# %%
using Pkg
Pkg.activate(@__DIR__)
# Out:
#   Activating environment at `~/Julia/doc/cscs_gpu_course/Project.toml`

# %%
using Revise
using CUDA
using BenchmarkTools

# %% [markdown]
# # Kernel analysis and optimization
#
# Once your application has been optimized, it's time to look at individual kernels. Initially, BenchmarkTools.jl and NSight Systems still are good tools to estimate the execution time of a kernel. For more insights, you can use the CUDA APIs, or use NSight Compute to dive deeply into a kernel's execution properties.

# %% [markdown]
# ## Case study: Batched RMSE
#
# As a case study, let's look at the batched RMSE calculation from the previous notebook again. Implementing such an operation in a single step is difficult, so let's start with a simplified version on a smaller input:

# %%
A = CUDA.rand(10,10)
B = CUDA.rand(10,10)
sqrt(sum((A-B).^2)/length(A))
# Out:
# 0.39697844f0

# %%
function rmse_kernel(C, A, B)  
    i = threadIdx().x

    # initialize the memory
    if i == 1
        C[1] = 0
    end
    sync_threads()
    
    # grid-stride loop to process each batch in a block
    a = A[i]
    b = B[i]
    CUDA.@atomic C[1] += (a-b)^2
    sync_threads()
    
    # finalize the computation
    if i == 1
        C[1] = sqrt(C[1] / length(A))
    end
    return
end;

# %%
C = CUDA.similar(A, 1)
@cuda threads=length(A) rmse_kernel(C,A,B)
C
# Out:
# 1-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.39697844

# %% [markdown]
# Now we need to extend this implementation to:
# - cover multiple batches
# - support inputs that don't fit in a single block
#
# As has already been covered before, a grid-stride loop is an easy way to make a single block process multiple items. Alternatively, we could launch multiple blocks, but that complicates synchronization and communication between blocks that need to process the same batch.

# %%
A = CUDA.rand(1024,1024)
B = CUDA.rand(1024,1024)
sqrt(sum((A-B).^2)/length(A))
# Out:
# 0.408413f0

# %%
function rmse_kernel(C, A, B)  
    # initialize the memory
    if threadIdx().x == 1
        C[1] = 0
    end
    sync_threads()
    
    # grid-stride loop to process each batch in a block
    for i in threadIdx().x:blockDim().x:length(A)
        a = A[i]
        b = B[i]
        CUDA.@atomic C[1] += (a-b)^2
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == 1
        C[1] = sqrt(C[1] / length(A))
    end
    return
end;

# %%
C = CUDA.similar(A, 1)
@cuda threads=256 rmse_kernel(C,A,B)
C
# Out:
# 1-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.40829936

# %% [markdown]
# Notice the slight differences between individual invocations, because of how the order of `@atomic` expressions is not guaranteed.

# %% [markdown]
# Finally, let's extend this to multiple batches:

# %%
N = 16
A = CUDA.rand(1024,1024,N)
B = CUDA.rand(1024,1024,N)
C = CUDA.similar(A, N)
sqrt.(sum((A.-B).^2; dims=1:(ndims(A)-1))./prod(size(A)[1:end-1]))
# Out:
# 1×1×16 CuArray{Float32, 3, CUDA.Mem.DeviceBuffer}:
# [:, :, 1] =
#  0.4085672
#
# [:, :, 2] =
#  0.40834135
#
# [:, :, 3] =
#  0.40830332
#
# ;;; …
#
# [:, :, 14] =
#  0.408083
#
# [:, :, 15] =
#  0.40812522
#
# [:, :, 16] =
#  0.40820798

# %% [markdown]
# A common pattern for dealing with multiple independent datasets or batches within a single kernel (i.e. without launching multiple kernels, one for each batch) so is to compute and pass separate cartesian indices to the kernel, and make sure those map into hardware indices the way we want. For example, here we have N-dimensional inputs whose last index represents the batch, so we can pass two separate cartesian indices:
# - one representing the 'main' iteration space, where the last index doesn't count
# - one representing the batches, having the samen dimensionality, but with only the last index set
#
# As we want each RMSE calculation between arrays from a single batch to happen within a single block (again, to simplify communication and synchronization), we should index the main cartesian indices object using a thread index, while using a block index for the batch indices. Within the kernel, we can then merge these two objects using the `max` operator to get a usable index. For more information on this technique, refer to the following blog post: https://julialang.org/blog/2016/02/iteration/.

# %%
Rmain = ntuple(i->i == ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
# Out:
# 1024×1024×1 CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}:
# [:, :, 1] =
#  CartesianIndex(1, 1, 1)     …  CartesianIndex(1, 1024, 1)
#  CartesianIndex(2, 1, 1)        CartesianIndex(2, 1024, 1)
#  CartesianIndex(3, 1, 1)        CartesianIndex(3, 1024, 1)
#  CartesianIndex(4, 1, 1)        CartesianIndex(4, 1024, 1)
#  CartesianIndex(5, 1, 1)        CartesianIndex(5, 1024, 1)
#  CartesianIndex(6, 1, 1)     …  CartesianIndex(6, 1024, 1)
#  CartesianIndex(7, 1, 1)        CartesianIndex(7, 1024, 1)
#  CartesianIndex(8, 1, 1)        CartesianIndex(8, 1024, 1)
#  CartesianIndex(9, 1, 1)        CartesianIndex(9, 1024, 1)
#  CartesianIndex(10, 1, 1)       CartesianIndex(10, 1024, 1)
#  CartesianIndex(11, 1, 1)    …  CartesianIndex(11, 1024, 1)
#  CartesianIndex(12, 1, 1)       CartesianIndex(12, 1024, 1)
#  CartesianIndex(13, 1, 1)       CartesianIndex(13, 1024, 1)
#  ⋮                           ⋱
#  CartesianIndex(1013, 1, 1)     CartesianIndex(1013, 1024, 1)
#  CartesianIndex(1014, 1, 1)     CartesianIndex(1014, 1024, 1)
#  CartesianIndex(1015, 1, 1)     CartesianIndex(1015, 1024, 1)
#  CartesianIndex(1016, 1, 1)  …  CartesianIndex(1016, 1024, 1)
#  CartesianIndex(1017, 1, 1)     CartesianIndex(1017, 1024, 1)
#  CartesianIndex(1018, 1, 1)     CartesianIndex(1018, 1024, 1)
#  CartesianIndex(1019, 1, 1)     CartesianIndex(1019, 1024, 1)
#  CartesianIndex(1020, 1, 1)     CartesianIndex(1020, 1024, 1)
#  CartesianIndex(1021, 1, 1)  …  CartesianIndex(1021, 1024, 1)
#  CartesianIndex(1022, 1, 1)     CartesianIndex(1022, 1024, 1)
#  CartesianIndex(1023, 1, 1)     CartesianIndex(1023, 1024, 1)
#  CartesianIndex(1024, 1, 1)     CartesianIndex(1024, 1024, 1)

# %%
Rbatch = ntuple(i->i != ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
# Out:
# 1×1×16 CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}:
# [:, :, 1] =
#  CartesianIndex(1, 1, 1)
#
# [:, :, 2] =
#  CartesianIndex(1, 1, 2)
#
# [:, :, 3] =
#  CartesianIndex(1, 1, 3)
#
# ;;; …
#
# [:, :, 14] =
#  CartesianIndex(1, 1, 14)
#
# [:, :, 15] =
#  CartesianIndex(1, 1, 15)
#
# [:, :, 16] =
#  CartesianIndex(1, 1, 16)

# %%
function rmse_kernel(C, A, B, Rmain, Rbatch)
    batch = blockIdx().x
    Ibatch = Rbatch[batch]
    
    # initialize the memory
    if threadIdx().x == 1
        C[batch] = 0
    end
    sync_threads()
    
    # grid-stride loop to process each batch in a block
    for i in threadIdx().x:blockDim().x:length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        CUDA.@atomic C[batch] += (a-b)^2
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == 1
        C[batch] = sqrt(C[batch] / length(Rmain))
    end
    return
end;

# %%
function rmse(C, A, B)
    Rmain = ntuple(i->i == ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    Rbatch = ntuple(i->i != ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    @cuda threads=256 blocks=N rmse_kernel(C, A, B, Rmain, Rbatch)
    return
end;

# %%
b = @benchmark CUDA.@sync rmse(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.4084522
#  0.40822744
#  0.40819687
#  0.40825972
#  0.40788049
#  0.40766144
#  0.4084545
#  0.4081247
#  0.40773115
#  0.408521
#  0.40833315
#  0.40828344
#  0.4080161
#  0.40795988
#  0.40800813
#  0.40809527
# BenchmarkTools.Trial: 249 samples with 1 evaluation.
#  Range (min … max):  19.581 ms …  30.245 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     19.947 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   20.074 ms ± 954.269 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#   ▆▆▆▅▅█▆
#   ████████▄▁▁▄▁▁▁▆▄▆▄▄▄▄▁▁▄▁▁▁▁▁▄▁▁▁▁▁▁▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆ ▆
#   19.6 ms       Histogram: log(frequency) by time      24.6 ms <
#
#  Memory estimate: 2.55 KiB, allocs estimate: 47.

# %% [markdown]
# Now that we have a fully functional implementation, let's benchmark in order to compare to the last notebook's implementation using array operations:

# %%
@benchmark CUDA.@sync rmse(C, A, B)
# Out:
# BenchmarkTools.Trial: 250 samples with 1 evaluation.
#  Range (min … max):  19.672 ms …  21.817 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     19.941 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   20.038 ms ± 313.213 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#      ▁▃█▅▂      ▁▂
#   ▃▄▆██████▇▆▃▆████▆▄▄▁▂▂▁▁▁▁▁▁▁▁▁▁▃▂▁▁▁▃▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂ ▃
#   19.7 ms         Histogram: frequency by time         21.7 ms <
#
#  Memory estimate: 2.55 KiB, allocs estimate: 47.

# %% [markdown]
# How slow is that?! To understand what's going in here, we'll need to dive deeper into this kernel.
#
# TODO: NSight Compute

# %% [markdown]
# We could try aggregating in shared memory instead, but ultimately this loop is slow because every iteration performs an atomic operation. There are several techniques to avoid this:
#
# - perform the reduction in parallel
# - use a shared memory buffer so that threads can communicate without intrinsics
# - use warp-level intrinsics for even finer-grained communication
#
# For more details on these techniques, refer to the following blog: https://developer.nvidia.com/blog/faster-parallel-reductions-kepler/
#
# CUDA.jl implements these techniques for its `mapreducedim!` implementation, and although the individual steps of that reduction aren't a stable API we can still use them to avoid having to implement our own parallel reduction:

# %%
function rmse_kernel_opt(C::AbstractArray{T}, A, B, Rmain, Rbatch) where T
    batch = blockIdx().x
    Ibatch = Rbatch[batch]
    
    # grid-stride loop to process each batch in a block
    val = zero(T)
    for i in threadIdx().x:blockDim().x:length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        val += CUDA.reduce_block(+, (a-b)^2, zero(T), #=shuffle=# Val(true))
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == 1
        C[batch] = sqrt(val / length(Rmain))
    end
    return
end;

# %%
function rmse_opt(C, A, B)
    Rmain = ntuple(i->i == ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    Rbatch = ntuple(i->i != ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    @cuda threads=256 blocks=N rmse_kernel_opt(C, A, B, Rmain, Rbatch)
    return
end;

# %%
b = @benchmark CUDA.@sync rmse_opt(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.40856707
#  0.40834144
#  0.40830347
#  0.40837765
#  0.40799418
#  0.4077742
#  0.40856826
#  0.40823975
#  0.40784803
#  0.40863705
#  0.408447
#  0.4083946
#  0.4081305
#  0.408083
#  0.40812513
#  0.40820822
# BenchmarkTools.Trial: 1224 samples with 1 evaluation.
#  Range (min … max):  3.973 ms …   5.691 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     4.040 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   4.081 ms ± 154.114 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#    █▅ ▂ ▃    ▇
#   ███▆███▅▆▅▇█▄▂▃▃▃▂▂▂▂▂▂▂▂▂▃▃▃▄▃▄▂▃▂▂▂▂▂▂▂▂▂▁▂▁▁▂▁▁▁▂▁▂▂▂▁▁▂ ▃
#   3.97 ms         Histogram: frequency by time        4.58 ms <
#
#  Memory estimate: 2.55 KiB, allocs estimate: 47.

# %% [markdown]
# Much better! But still slower than CUDA.jl's reduction. One reason is the launch configuration: We're hard-coding the number of threads to 256, for maximal compatibility with older GPUs, and only launch as many blocks as the number of batches. Is that good enough?

# %%
kernel = @cuda launch=false rmse_kernel_opt(C, A, B, CartesianIndices(axes(A)), CartesianIndices(axes(A)))
config = launch_configuration(kernel.fun)
# Out:
# (blocks = 48, threads = 512)

# %% [markdown]
# The occupancy API tells use that we should use:
# - 512 threads, to maximize occupancy within a SM
# - at least 48 blocks, to maximize use of the GPU
#
# Launching more threads is easy enough with a grid-stride loop, but launching more blocks needs a change to the index calculation. The reduction also needs to be adapted, since we may now be processing a single batch across multiple blocks. Lacking an efficient `reduce_grid`, the easiest solution is to re-introduce atomics. Those should not hurt performance, since they are only issues by a minimum of threads, and only once per kernel.
#
# To split the hardware block index into one for additionally indexing the main iteration space, and the batch number, I chose to use the 3D-aspect of these hardware indices. Alternatively, it's possible to use `fldmod1` to decompose a single index based on the length of the iterator.

# %%
function rmse_kernel_opt(C::AbstractArray{T}, A, B, Rmain, Rbatch) where T
    batch = blockIdx().y
    Ibatch = Rbatch[batch]
    
    # grid-stride loop to process each batch in a block
    val = zero(T)
    i0 = threadIdx().x + (blockIdx().x-1)*blockDim().x
    for i in i0:(blockDim().x*gridDim().x):length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        val += CUDA.reduce_block(+, (a-b)^2, zero(T), #=shuffle=# Val(true))
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == 1
        CUDA.@atomic C[batch] += val
    end
    return
end;

# %%
function rmse_opt(C, A, B)
    Rmain = ntuple(i->i == ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    Rbatch = ntuple(i->i != ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    
    fill!(C, 0)
    @cuda threads=512 blocks=(48,N) rmse_kernel_opt(C, A, B, Rmain, Rbatch)
    C .= sqrt.(C ./ length(Rmain))
    return
end;

# %%
b = @benchmark CUDA.@sync rmse_opt(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.40856716
#  0.40834135
#  0.40830332
#  0.40837765
#  0.4079943
#  0.40777388
#  0.40856865
#  0.40823978
#  0.40784812
#  0.40863714
#  0.40844733
#  0.40839452
#  0.40813056
#  0.408083
#  0.40812522
#  0.408208
# BenchmarkTools.Trial: 5977 samples with 1 evaluation.
#  Range (min … max):  818.630 μs …  10.566 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     828.739 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   833.407 μs ± 133.889 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                     ▃█▇▂
#   ▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▅████▇▅▅▅▆▆▅▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▂
#   819 μs           Histogram: frequency by time          848 μs <
#
#  Memory estimate: 3.14 KiB, allocs estimate: 57.

# %% [markdown]
# Much better. Let's actually use the launch configuration API at run time to make sure we use the best possible configuration for the GPU at hand:

# %%
function rmse_opt(C, A, B)
    Rmain = ntuple(i->i == ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    Rbatch = ntuple(i->i != ndims(A) ? Base.OneTo(1) : axes(A)[i], ndims(A)) |> CartesianIndices
    
    kernel = @cuda launch=false rmse_kernel_opt(C, A, B, Rmain, Rbatch)
    config = launch_configuration(kernel.fun)
    blocks_x = min(config.blocks, length(Rmain))
    threads = min(config.threads, cld(length(Rmain), blocks_x))
    blocks = (blocks_x, N)
    
    fill!(C, 0)
    kernel(C, A, B, Rmain, Rbatch; threads, blocks)
    C .= sqrt.(C ./ length(Rmain))
    return
end;

# %%
b = @benchmark CUDA.@sync rmse_opt(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.40856713
#  0.40834135
#  0.40830332
#  0.40837765
#  0.40799427
#  0.4077739
#  0.40856865
#  0.4082398
#  0.40784806
#  0.40863717
#  0.40844738
#  0.4083945
#  0.4081306
#  0.408083
#  0.40812522
#  0.408208
# BenchmarkTools.Trial: 5957 samples with 1 evaluation.
#  Range (min … max):  821.379 μs …  1.937 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     833.659 μs              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   836.315 μs ± 41.939 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                     ▅█▅▃▃
#   ▁▁▂▃▄▃▂▂▂▄▅▄▃▃▃▂▃▆██████▆▅▅▆▆▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▂
#   821 μs          Histogram: frequency by time          857 μs <
#
#  Memory estimate: 3.19 KiB, allocs estimate: 60.

# %% [markdown]
# Now we are getting close to the performance we'd expect. For the remaining optimizations, we will need to have a look at the generated code. It's recommended to start out with the LLVM code, which is the most readable:

# %%
@device_code_llvm debuginfo=:none rmse_opt(C,A,B)
# Out:
# ; PTX CompilerJob of kernel rmse_kernel_opt(CuDeviceVector{Float32, 1}, CuDeviceArray{Float32, 3, 1}, CuDeviceArray{Float32, 3, 1}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}) for sm_75
# define ptx_kernel void @_Z27julia_rmse_kernel_opt_1346513CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE([1 x i64] %state, { i8 addrspace(1)*, i64, [1 x i64] } %0, { i8 addrspace(1)*, i64, [3 x i64] } %1, { i8 addrspace(1)*, i64, [3 x i64] } %2, [1 x [3 x [1 x i64]]] %3, [1 x [3 x [1 x i64]]] %4) local_unnamed_addr #7 {
# entry:
#   %.fca.0.extract22 = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 0
#   %5 = alloca { i8 addrspace(1)*, i64, [3 x i64] }, align 8
#   %.fca.0.extract12 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 0
#   %6 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %5, i64 0, i32 0
#   store i8 addrspace(1)* %.fca.0.extract12, i8 addrspace(1)** %6, align 8
#   %.fca.1.extract14 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 1
#   %7 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %5, i64 0, i32 1
#   store i64 %.fca.1.extract14, i64* %7, align 8
#   %.fca.2.0.extract16 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 2, 0
#   %8 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %5, i64 0, i32 2, i64 0
#   store i64 %.fca.2.0.extract16, i64* %8, align 8
#   %.fca.2.1.extract18 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 2, 1
#   %9 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %5, i64 0, i32 2, i64 1
#   store i64 %.fca.2.1.extract18, i64* %9, align 8
#   %.fca.2.2.extract20 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 2, 2
#   %10 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %5, i64 0, i32 2, i64 2
#   store i64 %.fca.2.2.extract20, i64* %10, align 8
#   %11 = alloca { i8 addrspace(1)*, i64, [3 x i64] }, align 8
#   %.fca.0.extract10 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 0
#   %12 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %11, i64 0, i32 0
#   store i8 addrspace(1)* %.fca.0.extract10, i8 addrspace(1)** %12, align 8
#   %.fca.1.extract11 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 1
#   %13 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %11, i64 0, i32 1
#   store i64 %.fca.1.extract11, i64* %13, align 8
#   %.fca.2.0.extract = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 2, 0
#   %14 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %11, i64 0, i32 2, i64 0
#   store i64 %.fca.2.0.extract, i64* %14, align 8
#   %.fca.2.1.extract = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 2, 1
#   %15 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %11, i64 0, i32 2, i64 1
#   store i64 %.fca.2.1.extract, i64* %15, align 8
#   %.fca.2.2.extract = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 2, 2
#   %16 = getelementptr inbounds { i8 addrspace(1)*, i64, [3 x i64] }, { i8 addrspace(1)*, i64, [3 x i64] }* %11, i64 0, i32 2, i64 2
#   store i64 %.fca.2.2.extract, i64* %16, align 8
#   %17 = alloca [1 x [3 x [1 x i64]]], align 8
#   %.fca.0.0.0.extract4 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 0, 0
#   %18 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %17, i64 0, i64 0, i64 0, i64 0
#   store i64 %.fca.0.0.0.extract4, i64* %18, align 8
#   %.fca.0.1.0.extract6 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 1, 0
#   %19 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %17, i64 0, i64 0, i64 1, i64 0
#   store i64 %.fca.0.1.0.extract6, i64* %19, align 8
#   %.fca.0.2.0.extract8 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 2, 0
#   %20 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %17, i64 0, i64 0, i64 2, i64 0
#   store i64 %.fca.0.2.0.extract8, i64* %20, align 8
#   %21 = alloca [1 x [3 x [1 x i64]]], align 8
#   %.fca.0.0.0.extract = extractvalue [1 x [3 x [1 x i64]]] %4, 0, 0, 0
#   %22 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %21, i64 0, i64 0, i64 0, i64 0
#   store i64 %.fca.0.0.0.extract, i64* %22, align 8
#   %.fca.0.1.0.extract = extractvalue [1 x [3 x [1 x i64]]] %4, 0, 1, 0
#   %23 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %21, i64 0, i64 0, i64 1, i64 0
#   store i64 %.fca.0.1.0.extract, i64* %23, align 8
#   %.fca.0.2.0.extract = extractvalue [1 x [3 x [1 x i64]]] %4, 0, 2, 0
#   %24 = getelementptr inbounds [1 x [3 x [1 x i64]]], [1 x [3 x [1 x i64]]]* %21, i64 0, i64 0, i64 2, i64 0
#   store i64 %.fca.0.2.0.extract, i64* %24, align 8
#   %25 = alloca [1 x i64], align 8
#   %26 = alloca [1 x i64], align 8
#   %27 = alloca [1 x i64], align 8
#   %28 = alloca [1 x i64], align 8
#   %29 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.y()
#   %30 = add nuw nsw i32 %29, 1
#   %31 = zext i32 %30 to i64
#   %32 = getelementptr inbounds [1 x i64], [1 x i64]* %25, i64 0, i64 0
#   store i64 %31, i64* %32, align 8
#   %33 = mul i64 %.fca.0.1.0.extract, %.fca.0.0.0.extract
#   %34 = mul i64 %33, %.fca.0.2.0.extract
#   %35 = icmp sgt i64 %34, 0
#   %36 = select i1 %35, i64 %34, i64 0
#   %.not = icmp slt i64 %36, %31
#   %37 = bitcast i8 addrspace(1)* %.fca.0.extract12 to float addrspace(1)*
#   %38 = bitcast i8 addrspace(1)* %.fca.0.extract10 to float addrspace(1)*
#   br i1 %.not, label %L31, label %L34
#
# L31:                                              ; preds = %entry
#   call fastcc void @julia__throw_boundserror_13532([1 x i64] %state)
#   unreachable
#
# L34:                                              ; preds = %entry
#   %39 = icmp sgt i64 %.fca.0.0.0.extract, 0
#   %40 = icmp sgt i64 %.fca.0.1.0.extract, 0
#   %41 = select i1 %40, i64 %.fca.0.1.0.extract, i64 0
#   %42 = add nsw i64 %31, -1
#   br i1 %39, label %pass, label %fail
#
# L278:                                             ; preds = %L278.preheader, %L725
#   %value_phi9 = phi i64 [ %91, %L725 ], [ %113, %L278.preheader ]
#   %value_phi11 = phi float [ %90, %L725 ], [ 0.000000e+00, %L278.preheader ]
#   %43 = icmp slt i64 %value_phi9, 1
#   %44 = icmp sgt i64 %value_phi9, %126
#   %45 = or i1 %43, %44
#   br i1 %45, label %L300, label %L303
#
# L300:                                             ; preds = %L278
#   store i64 %value_phi9, i64* %124, align 8
#   call fastcc void @julia__throw_boundserror_13532([1 x i64] %state)
#   unreachable
#
# L303:                                             ; preds = %L278
#   %46 = add nsw i64 %value_phi9, -1
#   br i1 %127, label %pass13, label %fail12
#
# L507:                                             ; preds = %pass15
#   store i64 %165, i64* %134, align 8
#   call fastcc void @julia__throw_boundserror_13541([1 x i64] %state)
#   unreachable
#
# L510:                                             ; preds = %pass15
#   %47 = mul i64 %142, %.v
#   %reass.add53 = add i64 %163, %47
#   %reass.mul54 = mul i64 %reass.add53, %140
#   %48 = add i64 %reass.mul54, %162
#   %49 = icmp slt i64 %48, 1
#   %50 = icmp sgt i64 %48, %147
#   %51 = or i1 %49, %50
#   br i1 %51, label %L552, label %L555
#
# L552:                                             ; preds = %L510
#   store i64 %48, i64* %143, align 8
#   call fastcc void @julia__throw_boundserror_13541([1 x i64] %state)
#   unreachable
#
# L555:                                             ; preds = %L510
#   %52 = add nsw i64 %165, -1
#   %53 = getelementptr inbounds float, float addrspace(1)* %37, i64 %52
#   %54 = load float, float addrspace(1)* %53, align 4
#   %55 = add nsw i64 %48, -1
#   %56 = getelementptr inbounds float, float addrspace(1)* %38, i64 %55
#   %57 = load float, float addrspace(1)* %56, align 4
#   %58 = fsub float %54, %57
#   %59 = call i32 @llvm.nvvm.read.ptx.sreg.warpsize()
#   %60 = icmp eq i32 %59, 32
#   call void @llvm.assume(i1 %60)
#   %61 = call fastcc [2 x i32] @julia_fldmod1_13547([1 x i64] %state, i32 %106, i32 32)
#   %.fca.0.extract = extractvalue [2 x i32] %61, 0
#   %.fca.1.extract = extractvalue [2 x i32] %61, 1
#   %62 = fmul float %58, %58
#   %63 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %62, i32 1, i32 31)
#   %64 = fadd float %62, %63
#   %65 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %64, i32 2, i32 31)
#   %66 = fadd float %64, %65
#   %67 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %66, i32 4, i32 31)
#   %68 = fadd float %66, %67
#   %69 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %68, i32 8, i32 31)
#   %70 = fadd float %68, %69
#   %71 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %70, i32 16, i32 31)
#   %.not44 = icmp eq i32 %.fca.1.extract, 1
#   br i1 %.not44, label %L629, label %L637
#
# L629:                                             ; preds = %L555
#   %72 = fadd float %70, %71
#   %73 = add i32 %.fca.0.extract, -1
#   %74 = sext i32 %73 to i64
#   %75 = getelementptr inbounds [32 x float], [32 x float] addrspace(3)* @shmem, i64 0, i64 %74
#   store float %72, float addrspace(3)* %75, align 4
#   br label %L637
#
# L637:                                             ; preds = %L629, %L555
#   call void @llvm.nvvm.barrier0()
#   br i1 %.not47.not, label %L687, label %L696
#
# L687:                                             ; preds = %L637
#   %76 = add i32 %.fca.1.extract, -1
#   %77 = sext i32 %76 to i64
#   %78 = getelementptr inbounds [32 x float], [32 x float] addrspace(3)* @shmem, i64 0, i64 %77
#   %79 = load float, float addrspace(3)* %78, align 4
#   br label %L696
#
# L696:                                             ; preds = %L687, %L637
#   %value_phi24 = phi float [ %79, %L687 ], [ 0.000000e+00, %L637 ]
#   %.not48 = icmp eq i32 %.fca.0.extract, 1
#   br i1 %.not48, label %L715, label %L725
#
# L715:                                             ; preds = %L696
#   %80 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %value_phi24, i32 1, i32 31)
#   %81 = fadd float %value_phi24, %80
#   %82 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %81, i32 2, i32 31)
#   %83 = fadd float %81, %82
#   %84 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %83, i32 4, i32 31)
#   %85 = fadd float %83, %84
#   %86 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %85, i32 8, i32 31)
#   %87 = fadd float %85, %86
#   %88 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %87, i32 16, i32 31)
#   %89 = fadd float %87, %88
#   br label %L725
#
# L725:                                             ; preds = %L715, %L696
#   %value_phi27 = phi float [ %value_phi24, %L696 ], [ %89, %L715 ]
#   %90 = fadd float %value_phi11, %value_phi27
#   %.not51 = icmp eq i64 %value_phi9, %118
#   %91 = add i64 %value_phi9, %148
#   br i1 %.not51, label %L739.loopexit, label %L278
#
# L739.loopexit:                                    ; preds = %L725
#   store i64 %118, i64* %124, align 8
#   store i64 %165, i64* %134, align 8
#   store i64 %48, i64* %143, align 8
#   br label %L739
#
# L739:                                             ; preds = %pass2, %L739.loopexit
#   %value_phi31 = phi float [ 0.000000e+00, %pass2 ], [ %90, %L739.loopexit ]
#   call void @llvm.nvvm.barrier0()
#   %.not52 = icmp eq i32 %105, 0
#   br i1 %.not52, label %L754, label %L766
#
# L754:                                             ; preds = %L739
#   %92 = shl nuw nsw i32 %29, 2
#   %93 = zext i32 %92 to i64
#   %94 = getelementptr i8, i8 addrspace(1)* %.fca.0.extract22, i64 %93
#   %95 = bitcast i8 addrspace(1)* %94 to float addrspace(1)*
#   %96 = atomicrmw fadd float addrspace(1)* %95, float %value_phi31 acq_rel
#   br label %L766
#
# L766:                                             ; preds = %L754, %L739
#   ret void
#
# fail:                                             ; preds = %L34
#   call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception122 to i64))
#   call fastcc void @gpu_signal_exception([1 x i64] %state)
#   call void asm sideeffect "exit;", ""() #5
#   unreachable
#
# pass:                                             ; preds = %L34
#   %97 = udiv i64 %42, %.fca.0.0.0.extract
#   %98 = mul i64 %97, %.fca.0.0.0.extract
#   %99 = sub i64 %42, %98
#   %100 = add i64 %99, 1
#   br i1 %40, label %pass2, label %fail1
#
# fail1:                                            ; preds = %pass
#   call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception122 to i64))
#   call fastcc void @gpu_signal_exception([1 x i64] %state)
#   call void asm sideeffect "exit;", ""() #5
#   unreachable
#
# pass2:                                            ; preds = %pass
#   %101 = udiv i64 %97, %.fca.0.1.0.extract
#   %102 = mul i64 %101, %41
#   %103 = sub i64 %97, %102
#   %104 = add i64 %103, 1
#   %105 = call i32 @llvm.nvvm.read.ptx.sreg.tid.x()
#   %106 = add nuw nsw i32 %105, 1
#   %107 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.x()
#   %108 = zext i32 %107 to i64
#   %109 = call i32 @llvm.nvvm.read.ptx.sreg.ntid.x()
#   %110 = zext i32 %109 to i64
#   %111 = mul nuw nsw i64 %110, %108
#   %112 = zext i32 %106 to i64
#   %113 = add nuw nsw i64 %111, %112
#   %114 = call i32 @llvm.nvvm.read.ptx.sreg.nctaid.x()
#   %115 = mul i32 %114, %109
#   %116 = mul i64 %.fca.0.1.0.extract6, %.fca.0.0.0.extract4
#   %117 = mul i64 %116, %.fca.0.2.0.extract8
#   %118 = call fastcc i64 @julia_steprange_last_13549([1 x i64] %state, i64 %113, i32 %115, i64 %117)
#   %119 = icmp ne i64 %113, %118
#   %120 = icmp sgt i32 %115, 0
#   %121 = icmp slt i64 %113, %118
#   %122 = xor i1 %120, %121
#   %123 = and i1 %119, %122
#   br i1 %123, label %L739, label %L278.preheader
#
# L278.preheader:                                   ; preds = %pass2
#   %124 = getelementptr inbounds [1 x i64], [1 x i64]* %26, i64 0, i64 0
#   %125 = icmp sgt i64 %117, 0
#   %126 = select i1 %125, i64 %117, i64 0
#   %127 = icmp sgt i64 %.fca.0.0.0.extract4, 0
#   %128 = icmp sgt i64 %.fca.0.1.0.extract6, 0
#   %129 = select i1 %128, i64 %.fca.0.1.0.extract6, i64 0
#   %130 = icmp sgt i64 %.fca.2.0.extract16, 0
#   %131 = select i1 %130, i64 %.fca.2.0.extract16, i64 0
#   %132 = icmp sgt i64 %.fca.2.1.extract18, 0
#   %133 = select i1 %132, i64 %.fca.2.1.extract18, i64 0
#   %134 = getelementptr inbounds [1 x i64], [1 x i64]* %27, i64 0, i64 0
#   %135 = mul i64 %.fca.2.1.extract18, %.fca.2.0.extract16
#   %136 = mul i64 %135, %.fca.2.2.extract20
#   %137 = icmp sgt i64 %136, 0
#   %138 = select i1 %137, i64 %136, i64 0
#   %139 = icmp sgt i64 %.fca.2.0.extract, 0
#   %140 = select i1 %139, i64 %.fca.2.0.extract, i64 0
#   %141 = icmp sgt i64 %.fca.2.1.extract, 0
#   %142 = select i1 %141, i64 %.fca.2.1.extract, i64 0
#   %143 = getelementptr inbounds [1 x i64], [1 x i64]* %28, i64 0, i64 0
#   %144 = mul i64 %.fca.2.1.extract, %.fca.2.0.extract
#   %145 = mul i64 %144, %.fca.2.2.extract
#   %146 = icmp sgt i64 %145, 0
#   %147 = select i1 %146, i64 %145, i64 0
#   %148 = sext i32 %115 to i64
#   %149 = lshr i32 %109, 5
#   %150 = and i32 %109, 992
#   %151 = icmp ne i32 %150, %109
#   %152 = zext i1 %151 to i32
#   %153 = add nuw nsw i32 %149, %152
#   %.not47.not = icmp ult i32 %105, %153
#   br label %L278
#
# fail12:                                           ; preds = %L303
#   call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception122 to i64))
#   call fastcc void @gpu_signal_exception([1 x i64] %state)
#   call void asm sideeffect "exit;", ""() #5
#   unreachable
#
# pass13:                                           ; preds = %L303
#   %154 = udiv i64 %46, %.fca.0.0.0.extract4
#   %155 = mul i64 %154, %.fca.0.0.0.extract4
#   %156 = sub nuw i64 %46, %155
#   br i1 %128, label %pass15, label %fail14
#
# fail14:                                           ; preds = %pass13
#   call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception122 to i64))
#   call fastcc void @gpu_signal_exception([1 x i64] %state)
#   call void asm sideeffect "exit;", ""() #5
#   unreachable
#
# pass15:                                           ; preds = %pass13
#   %157 = add nuw nsw i64 %156, 1
#   %158 = udiv i64 %154, %.fca.0.1.0.extract6
#   %159 = mul i64 %158, %129
#   %160 = sub i64 %154, %159
#   %161 = add i64 %160, 1
#   %.not39.not = icmp sgt i64 %100, %156
#   %162 = select i1 %.not39.not, i64 %100, i64 %157
#   %.not40 = icmp slt i64 %104, %161
#   %.not41 = icmp slt i64 %101, %158
#   %.v = select i1 %.not41, i64 %158, i64 %101
#   %163 = select i1 %.not40, i64 %160, i64 %103
#   %164 = mul i64 %.v, %133
#   %reass.add = add i64 %163, %164
#   %reass.mul = mul i64 %reass.add, %131
#   %165 = add i64 %reass.mul, %162
#   %166 = icmp slt i64 %165, 1
#   %167 = icmp sgt i64 %165, %138
#   %168 = or i1 %166, %167
#   br i1 %168, label %L507, label %L510
# }
# ; PTX CompilerJob of kernel broadcast_kernel(CUDA.CuKernelContext, CuDeviceVector{Float32, 1}, Base.Broadcast.Broadcasted{Nothing, Tuple{Base.OneTo{Int64}}, typeof(sqrt), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1}, Nothing, typeof(/), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Int64}}}}, Int64) for sm_75
# define ptx_kernel void @_Z28julia_broadcast_kernel_1364715CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_([1 x i64] %state, { i8 addrspace(1)*, i64, [1 x i64] } %0, { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, i64 signext %2) local_unnamed_addr #1 {
# entry:
#   %.fca.2.0.extract = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 2, 0
#   %.fca.0.0.0.0.2.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 2, 0
#   %.inv = icmp sgt i64 %2, 0
#   %3 = select i1 %.inv, i64 %2, i64 0
#   br i1 %.inv, label %L13.preheader, label %L77
#
# L13.preheader:                                    ; preds = %entry
#   %.fca.0.0.0.1.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 1
#   %.fca.0.0.0.0.1.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 1, 0
#   %.fca.0.0.0.0.0.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 0, 0
#   %.fca.0.extract = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 0
#   %4 = call i32 @llvm.nvvm.read.ptx.sreg.tid.x()
#   %5 = add nuw nsw i32 %4, 1
#   %6 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.x()
#   %7 = zext i32 %6 to i64
#   %8 = call i32 @llvm.nvvm.read.ptx.sreg.ntid.x()
#   %9 = zext i32 %8 to i64
#   %10 = mul nuw nsw i64 %9, %7
#   %11 = zext i32 %5 to i64
#   %12 = add nuw nsw i64 %10, %11
#   %13 = call i32 @llvm.nvvm.read.ptx.sreg.nctaid.x()
#   %14 = mul i32 %8, %13
#   %15 = sext i32 %14 to i64
#   %16 = and i8 %.fca.0.0.0.0.1.0.extract, 1
#   %.not16 = icmp eq i8 %16, 0
#   %17 = bitcast i8 addrspace(1)* %.fca.0.0.0.0.0.0.extract to float addrspace(1)*
#   %18 = sitofp i64 %.fca.0.0.0.1.extract to float
#   %19 = bitcast i8 addrspace(1)* %.fca.0.extract to float addrspace(1)*
#   br i1 %.not16, label %L13.preheader.split.us, label %L13
#
# L13.preheader.split.us:                           ; preds = %L13.preheader
#   %20 = add i64 %.fca.0.0.0.0.2.0.extract, -1
#   %21 = getelementptr inbounds float, float addrspace(1)* %17, i64 %20
#   br label %L13.us
#
# L13.us:                                           ; preds = %__nv_sqrtf.exit.us, %L13.preheader.split.us
#   %value_phi3.us = phi i64 [ %41, %__nv_sqrtf.exit.us ], [ 1, %L13.preheader.split.us ]
#   %22 = add nsw i64 %value_phi3.us, -1
#   %23 = mul i64 %22, %15
#   %24 = add i64 %12, %23
#   %.not.us = icmp slt i64 %.fca.2.0.extract, %24
#   br i1 %.not.us, label %L77, label %L150.us
#
# L150.us:                                          ; preds = %L13.us
#   %25 = load float, float addrspace(1)* %21, align 4
#   %26 = fdiv float %25, %18
#   %27 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([11 x i8], [11 x i8]* @.str, i64 0, i64 0)) #3
#   %.not.i.us = icmp eq i32 %27, 0
#   %28 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([17 x i8], [17 x i8]* @.str.2, i64 0, i64 0)) #3
#   %.not1.i.us = icmp eq i32 %28, 0
#   br i1 %.not.i.us, label %34, label %29
#
# 29:                                               ; preds = %L150.us
#   br i1 %.not1.i.us, label %32, label %30
#
# 30:                                               ; preds = %29
#   %31 = call float @llvm.nvvm.sqrt.rn.ftz.f(float %26) #3
#   br label %__nv_sqrtf.exit.us
#
# 32:                                               ; preds = %29
#   %33 = call float @llvm.nvvm.sqrt.approx.ftz.f(float %26) #3
#   br label %__nv_sqrtf.exit.us
#
# 34:                                               ; preds = %L150.us
#   br i1 %.not1.i.us, label %37, label %35
#
# 35:                                               ; preds = %34
#   %36 = call float @llvm.sqrt.f32(float %26) #3
#   br label %__nv_sqrtf.exit.us
#
# 37:                                               ; preds = %34
#   %38 = call float @llvm.nvvm.sqrt.approx.f(float %26) #3
#   br label %__nv_sqrtf.exit.us
#
# __nv_sqrtf.exit.us:                               ; preds = %37, %35, %32, %30
#   %.0.i.us = phi float [ %31, %30 ], [ %33, %32 ], [ %36, %35 ], [ %38, %37 ]
#   %39 = add i64 %24, -1
#   %40 = getelementptr inbounds float, float addrspace(1)* %19, i64 %39
#   store float %.0.i.us, float addrspace(1)* %40, align 4
#   %.not17.us = icmp eq i64 %value_phi3.us, %3
#   %41 = add nuw i64 %value_phi3.us, 1
#   br i1 %.not17.us, label %L77, label %L13.us
#
# L13:                                              ; preds = %__nv_sqrtf.exit, %L13.preheader
#   %value_phi3 = phi i64 [ %62, %__nv_sqrtf.exit ], [ 1, %L13.preheader ]
#   %42 = add nsw i64 %value_phi3, -1
#   %43 = mul i64 %42, %15
#   %44 = add i64 %12, %43
#   %.not = icmp slt i64 %.fca.2.0.extract, %44
#   br i1 %.not, label %L77, label %L150
#
# L77:                                              ; preds = %__nv_sqrtf.exit, %L13, %__nv_sqrtf.exit.us, %L13.us, %entry
#   ret void
#
# L150:                                             ; preds = %L13
#   %45 = add i64 %44, -1
#   %46 = getelementptr inbounds float, float addrspace(1)* %17, i64 %45
#   %47 = load float, float addrspace(1)* %46, align 4
#   %48 = fdiv float %47, %18
#   %49 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([11 x i8], [11 x i8]* @.str, i64 0, i64 0)) #3
#   %.not.i = icmp eq i32 %49, 0
#   %50 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([17 x i8], [17 x i8]* @.str.2, i64 0, i64 0)) #3
#   %.not1.i = icmp eq i32 %50, 0
#   br i1 %.not.i, label %56, label %51
#
# 51:                                               ; preds = %L150
#   br i1 %.not1.i, label %54, label %52
#
# 52:                                               ; preds = %51
#   %53 = call float @llvm.nvvm.sqrt.rn.ftz.f(float %48) #3
#   br label %__nv_sqrtf.exit
#
# 54:                                               ; preds = %51
#   %55 = call float @llvm.nvvm.sqrt.approx.ftz.f(float %48) #3
#   br label %__nv_sqrtf.exit
#
# 56:                                               ; preds = %L150
#   br i1 %.not1.i, label %59, label %57
#
# 57:                                               ; preds = %56
#   %58 = call float @llvm.sqrt.f32(float %48) #3
#   br label %__nv_sqrtf.exit
#
# 59:                                               ; preds = %56
#   %60 = call float @llvm.nvvm.sqrt.approx.f(float %48) #3
#   br label %__nv_sqrtf.exit
#
# __nv_sqrtf.exit:                                  ; preds = %59, %57, %54, %52
#   %.0.i = phi float [ %53, %52 ], [ %55, %54 ], [ %58, %57 ], [ %60, %59 ]
#   %61 = getelementptr inbounds float, float addrspace(1)* %19, i64 %45
#   store float %.0.i, float addrspace(1)* %61, align 4
#   %.not17 = icmp eq i64 %value_phi3, %3
#   %62 = add nuw i64 %value_phi3, 1
#   br i1 %.not17, label %L77, label %L13
# }

# %% [markdown]
# Generally, for GPU kernels we want straight-line code, minimizing the amount of branches, while also reducing the amount of data that needs to be kept in registers. You can easily inspect the former using the compiled kernel object:

# %%
kernel = @cuda launch=false rmse_kernel_opt(C, A, B, CartesianIndices(axes(A)), CartesianIndices(axes(A)))
CUDA.registers(kernel)
# Out:
# 98

# %% [markdown]
# It's important to minimize the amount of registers, because it determines how much threads can be launched as part of a single block:

# %%
CUDA.maxthreads(kernel)
# Out:
# 512

# %% [markdown]
# Note that this is the same number as reported by the occupancy API.
#
# If we now look closer at the generated code, we can quickly see a bunch of branches because of bounds checking. Typically, those function calls also require data to be prepared and put into registers, so eliminating bounds checks should both remove unneeded branches as well as reduce register pressure:

# %%
function rmse_kernel_opt(C::AbstractArray{T}, A, B, Rmain, Rbatch) where T
    batch = blockIdx().y
    Ibatch = @inbounds Rbatch[batch]
    
    # grid-stride loop to process each batch in a block
    val = zero(T)
    i0 = threadIdx().x + (blockIdx().x-1)*blockDim().x
    @inbounds for i in i0:(blockDim().x*gridDim().x):length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        val += CUDA.reduce_block(+, (a-b)^2, zero(T), #=shuffle=# Val(true))
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == 1
        @inbounds CUDA.@atomic C[batch] += val
    end
    return
end;

# %%
b = @benchmark CUDA.@sync rmse_opt(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.40864596
#  0.40841642
#  0.4083755
#  0.40845305
#  0.4080715
#  0.40784878
#  0.4086396
#  0.4083154
#  0.40791878
#  0.40870374
#  0.40852144
#  0.40846443
#  0.40819678
#  0.40815797
#  0.40820137
#  0.40828073
# BenchmarkTools.Trial: 6734 samples with 1 evaluation.
#  Range (min … max):  687.711 μs … 50.028 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     702.802 μs              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   739.422 μs ±  1.115 ms  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                      ▃▆█▇▇▆▄▂
#   ▂▁▁▁▁▂▂▂▂▂▃▃▄▅▅▅▅▅▇█████████▇▆▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂ ▃
#   688 μs          Histogram: frequency by time          727 μs <
#
#  Memory estimate: 3.19 KiB, allocs estimate: 60.

# %%
kernel = @cuda launch=false rmse_kernel_opt(C, A, B, CartesianIndices(axes(A)), CartesianIndices(axes(A)))
CUDA.registers(kernel)
# Out:
# 90

# %%
CUDA.maxthreads(kernel)
# Out:
# 640

# %% [markdown]
# Another common source of register pressure is the use of 64-bit integers where only 32-bits are required. For example, the hardware's indices are 32-bit integers, but Julia's literals here are Int64's which results in expressions like `blockIdx().x-1` to be promoted to 64-bits integers. We can avoid this by using `Int32` indices:

# %%
function rmse_kernel_opt(C::AbstractArray{T}, A, B, Rmain, Rbatch) where T
    batch = blockIdx().y
    Ibatch = @inbounds Rbatch[batch]
    
    # grid-stride loop to process each batch in a block
    val = zero(T)
    i0 = threadIdx().x + (blockIdx().x-Int32(1))*blockDim().x
    @inbounds for i in i0:(blockDim().x*gridDim().x):length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        val += CUDA.reduce_block(+, (a-b)^2, zero(T), #=shuffle=# Val(true))
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == Int32(1)
        @inbounds CUDA.@atomic C[batch] += val
    end
    return
end
# Out:
# rmse_kernel_opt (generic function with 1 method)

# %%
kernel = @cuda launch=false rmse_kernel_opt(C, A, B, CartesianIndices(axes(A)), CartesianIndices(axes(A)))
CUDA.registers(kernel)
# Out:
# 88

# %% [markdown]
# If we look even closer at the generated code, there is another exception being thrown from the `div` function in Base:

# %%
@device_code_llvm rmse_opt(C,A,B)
# Out:
# ; PTX CompilerJob of kernel rmse_kernel_opt(CuDeviceVector{Float32, 1}, CuDeviceArray{Float32, 3, 1}, CuDeviceArray{Float32, 3, 1}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}) for sm_75
# ;  @ In[95]:1 within `rmse_kernel_opt`
# define ptx_kernel void @_Z27julia_rmse_kernel_opt_1395213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE([1 x i64] %state, { i8 addrspace(1)*, i64, [1 x i64] } %0, { i8 addrspace(1)*, i64, [3 x i64] } %1, { i8 addrspace(1)*, i64, [3 x i64] } %2, [1 x [3 x [1 x i64]]] %3, [1 x [3 x [1 x i64]]] %4) local_unnamed_addr #6 {
# entry:
#   %.fca.0.extract29 = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 0
#   %.fca.0.extract17 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 0
#   %.fca.2.0.extract19 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 2, 0
#   %.fca.2.1.extract20 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %1, 2, 1
#   %.fca.0.extract10 = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 0
#   %.fca.2.0.extract = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 2, 0
#   %.fca.2.1.extract = extractvalue { i8 addrspace(1)*, i64, [3 x i64] } %2, 2, 1
#   %.fca.0.0.0.extract4 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 0, 0
#   %.fca.0.1.0.extract6 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 1, 0
#   %.fca.0.2.0.extract8 = extractvalue [1 x [3 x [1 x i64]]] %3, 0, 2, 0
#   %.fca.0.0.0.extract = extractvalue [1 x [3 x [1 x i64]]] %4, 0, 0, 0
#   %.fca.0.1.0.extract = extractvalue [1 x [3 x [1 x i64]]] %4, 0, 1, 0
# ;  @ In[95]:2 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:78 within `#blockIdx`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:56 within `blockIdx_y`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `_index`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#       %5 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.y()
# ; └└└└
# ;  @ In[95]:3 within `rmse_kernel_opt`
# ; ┌ @ abstractarray.jl:1218 within `getindex`
# ; │┌ @ abstractarray.jl:1257 within `_getindex`
# ; ││┌ @ abstractarray.jl:1264 within `_to_subscript_indices`
# ; │││┌ @ abstractarray.jl:1286 within `_unsafe_ind2sub`
# ; ││││┌ @ abstractarray.jl:2559 within `_ind2sub`
# ; │││││┌ @ multidimensional.jl:352 within `axes`
# ; ││││││┌ @ tuple.jl:223 within `map`
# ; │││││││┌ @ abstractarray.jl:116 within `axes1`
# ; ││││││││┌ @ range.jl:643 within `axes`
# ; │││││││││┌ @ range.jl:413 within `oneto`
# ; ││││││││││┌ @ range.jl:411 within `OneTo` @ range.jl:398
# ; │││││││││││┌ @ promotion.jl:479 within `max`
#               %6 = icmp sgt i64 %.fca.0.0.0.extract, 0
#               %7 = icmp sgt i64 %.fca.0.1.0.extract, 0
#               %8 = select i1 %7, i64 %.fca.0.1.0.extract, i64 0
# ; │││││└└└└└└└
# ; │││││ @ abstractarray.jl:2559 within `_ind2sub` @ abstractarray.jl:2597
# ; │││││┌ @ int.jl:86 within `-`
#         %9 = zext i32 %5 to i64
# ; │││││└
# ; │││││┌ @ abstractarray.jl:2610 within `_ind2sub_recurse`
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           br i1 %6, label %pass, label %fail
#
# L276:                                             ; preds = %L276.preheader.split.L276.preheader.split.split_crit_edge, %L723
#           %value_phi9 = phi i64 [ %62, %L723 ], [ %87, %L276.preheader.split.L276.preheader.split.split_crit_edge ]
#           %value_phi11 = phi float [ %61, %L723 ], [ 0.000000e+00, %L276.preheader.split.L276.preheader.split.split_crit_edge ]
# ; └└└└└└└└
# ;  @ In[95]:9 within `rmse_kernel_opt`
# ; ┌ @ abstractarray.jl:1218 within `getindex`
# ; │┌ @ abstractarray.jl:1257 within `_getindex`
# ; ││┌ @ abstractarray.jl:1264 within `_to_subscript_indices`
# ; │││┌ @ abstractarray.jl:1286 within `_unsafe_ind2sub`
# ; ││││┌ @ abstractarray.jl:2559 within `_ind2sub` @ abstractarray.jl:2597
# ; │││││┌ @ int.jl:86 within `-`
#         %10 = add i64 %value_phi9, -1
# ; │││││└
# ; │││││┌ @ abstractarray.jl:2610 within `_ind2sub_recurse`
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           %11 = sdiv i64 %10, %.fca.0.0.0.extract4
# ; │││││└└└
# ; │││││┌ @ abstractarray.jl:2611 within `_ind2sub_recurse`
# ; ││││││┌ @ int.jl:88 within `*`
#          %12 = mul i64 %11, %.fca.0.0.0.extract4
# ; ││││││└
# ; ││││││┌ @ int.jl:86 within `-`
#          %13 = sub i64 %10, %12
# ; ││││││└
# ; ││││││┌ @ int.jl:87 within `+`
#          %14 = add i64 %13, 1
# ; ││││││└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2610
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           %15 = sdiv i64 %11, %.fca.0.1.0.extract6
# ; ││││││└└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2611
# ; ││││││┌ @ int.jl:88 within `*`
#          %16 = mul i64 %15, %96
# ; ││││││└
# ; ││││││┌ @ int.jl:86 within `-`
#          %17 = sub i64 %11, %16
# ; ││││││└
# ; ││││││┌ @ int.jl:87 within `+`
#          %18 = add i64 %17, 1
# ; ││││││└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2611 @ abstractarray.jl:2605
# ; ││││││┌ @ abstractarray.jl:2615 within `_lookup`
# ; │││││││┌ @ int.jl:87 within `+`
#           %19 = add i64 %15, 1
# ; └└└└└└└└
# ;  @ In[95]:10 within `rmse_kernel_opt`
# ; ┌ @ multidimensional.jl:120 within `max`
# ; │┌ @ tuple.jl:250 within `map`
# ; ││┌ @ promotion.jl:479 within `max`
# ; │││┌ @ int.jl:83 within `<`
#       %.not = icmp slt i64 %71, %14
# ; ││└└
# ; ││ @ tuple.jl:250 within `map` @ tuple.jl:247
# ; ││┌ @ promotion.jl:479 within `max`
# ; │││┌ @ int.jl:83 within `<`
#       %.not41 = icmp slt i64 %75, %18
#       %.not42 = icmp slt i64 %76, %19
# ; └└└└
# ;  @ In[95]:11 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex`
# ; │┌ @ abstractarray.jl:1251 within `_to_linear_index`
# ; ││┌ @ abstractarray.jl:2554 within `_sub2ind` @ abstractarray.jl:2570
# ; │││┌ @ abstractarray.jl:2586 within `_sub2ind_recurse` @ abstractarray.jl:2586
# ; ││││┌ @ abstractarray.jl:2593 within `offsetin`
# ; │││││┌ @ int.jl:86 within `-`
#         %20 = select i1 %.not41, i64 %17, i64 %74
# ; ││││└└
# ; ││││ @ abstractarray.jl:2586 within `_sub2ind_recurse` @ abstractarray.jl:2586 @ abstractarray.jl:2586
# ; ││││┌ @ abstractarray.jl:2593 within `offsetin`
# ; │││││┌ @ int.jl:86 within `-`
#         %21 = select i1 %.not42, i64 %15, i64 %72
# ; ││││└└
# ; ││││┌ @ int.jl:88 within `*`
#        %22 = mul i64 %21, %100
#        %reass.add = add i64 %20, %22
#        %reass.mul = mul i64 %reass.add, %98
# ; ││││└
# ; ││││┌ @ int.jl:87 within `+`
#        %23 = select i1 %.not, i64 %13, i64 %70
# ; │└└└└
# ; │ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:202
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:121 within `arrayref`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:129 within `arrayref_bits`
# ; │││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:81 within `unsafe_load`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `pointerref`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; ││││││┌ @ int.jl:86 within `-`
#          %24 = add i64 %23, %reass.mul
# ; ││││││└
#         %25 = getelementptr inbounds float, float addrspace(1)* %101, i64 %24
#         %26 = load float, float addrspace(1)* %25, align 4
# ; └└└└└└
# ;  @ In[95]:12 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex`
# ; │┌ @ abstractarray.jl:1251 within `_to_linear_index`
# ; ││┌ @ abstractarray.jl:2554 within `_sub2ind` @ abstractarray.jl:2570
# ; │││┌ @ abstractarray.jl:2586 within `_sub2ind_recurse` @ abstractarray.jl:2586 @ abstractarray.jl:2586
# ; ││││┌ @ int.jl:88 within `*`
#        %27 = mul i64 %21, %105
#        %reass.add57 = add i64 %20, %27
#        %reass.mul58 = mul i64 %reass.add57, %103
# ; │└└└└
# ; │ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:202
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:121 within `arrayref`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:129 within `arrayref_bits`
# ; │││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:81 within `unsafe_load`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `pointerref`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; ││││││┌ @ int.jl:86 within `-`
#          %28 = add i64 %23, %reass.mul58
# ; ││││││└
#         %29 = getelementptr inbounds float, float addrspace(1)* %106, i64 %28
#         %30 = load float, float addrspace(1)* %29, align 4
# ; └└└└└└
# ;  @ In[95]:13 within `rmse_kernel_opt`
# ; ┌ @ float.jl:401 within `-`
#    %31 = fsub float %26, %30
# ; └
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:25 within `reduce_block`
#    %32 = call fastcc [2 x i32] @julia_fldmod1_14034([1 x i64] %state, i32 %78, i32 32)
#    %.fca.0.extract = extractvalue [2 x i32] %32, 0
#    %.fca.1.extract = extractvalue [2 x i32] %32, 1
# ; └
# ; ┌ @ intfuncs.jl:312 within `literal_pow`
# ; │┌ @ float.jl:404 within `*`
#     %33 = fmul float %31, %31
# ; └└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:28 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:12 within `reduce_warp`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %34 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %33, i32 1, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %35 = fadd float %33, %34
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %36 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %35, i32 2, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %37 = fadd float %35, %36
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %38 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %37, i32 4, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %39 = fadd float %37, %38
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %40 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %39, i32 8, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %41 = fadd float %39, %40
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %42 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %41, i32 16, i32 31)
# ; └└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:31 within `reduce_block`
# ; │┌ @ promotion.jl:418 within `==` @ promotion.jl:468
#     %.not45 = icmp eq i32 %.fca.1.extract, 1
# ; │└
#    br i1 %.not45, label %L627, label %L635
#
# L627:                                             ; preds = %L276
# ; └
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:28 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:12 within `reduce_warp`
# ; ││┌ @ float.jl:398 within `+`
#      %43 = fadd float %41, %42
# ; └└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:32 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:204 within `setindex!`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:163 within `arrayset`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:172 within `arrayset_bits`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:84 within `unsafe_store!`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `pointerset`
# ; ││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; │││││││┌ @ int.jl:86 within `-`
#           %44 = add i32 %.fca.0.extract, -1
# ; │││││││└
# ; │││││││┌ @ boot.jl:762 within `Int64`
# ; ││││││││┌ @ boot.jl:681 within `toInt64`
#            %45 = sext i32 %44 to i64
# ; │││││││└└
#          %46 = getelementptr inbounds [32 x float], [32 x float] addrspace(3)* @shmem, i64 0, i64 %45
#          store float %43, float addrspace(3)* %46, align 4
# ; ││└└└└└
#     br label %L635
#
# L635:                                             ; preds = %L627, %L276
# ; └└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:36 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:14 within `sync_threads`
#     call void @llvm.nvvm.barrier0()
# ; └└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:39 within `reduce_block`
#    br i1 %.not48.not, label %L685, label %L694
#
# L685:                                             ; preds = %L635
# ; └
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:40 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:202 within `getindex`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:121 within `arrayref`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:129 within `arrayref_bits`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:81 within `unsafe_load`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `pointerref`
# ; ││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; │││││││┌ @ int.jl:86 within `-`
#           %47 = add i32 %.fca.1.extract, -1
# ; │││││││└
# ; │││││││┌ @ boot.jl:762 within `Int64`
# ; ││││││││┌ @ boot.jl:681 within `toInt64`
#            %48 = sext i32 %47 to i64
# ; │││││││└└
#          %49 = getelementptr inbounds [32 x float], [32 x float] addrspace(3)* @shmem, i64 0, i64 %48
#          %50 = load float, float addrspace(3)* %49, align 4
# ; └└└└└└└
# ;  @ In[95]:8 within `rmse_kernel_opt`
# ; ┌ @ range.jl:828 within `iterate`
#    br label %L694
#
# L694:                                             ; preds = %L685, %L635
#    %value_phi24 = phi float [ %50, %L685 ], [ 0.000000e+00, %L635 ]
# ; └
# ;  @ In[95]:13 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:46 within `reduce_block`
# ; │┌ @ promotion.jl:418 within `==` @ promotion.jl:468
#     %.not49 = icmp eq i32 %.fca.0.extract, 1
# ; │└
#    br i1 %.not49, label %L713, label %L723
#
# L713:                                             ; preds = %L694
# ; └
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:47 within `reduce_block`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:12 within `reduce_warp`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %51 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %value_phi24, i32 1, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %52 = fadd float %value_phi24, %51
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %53 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %52, i32 2, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %54 = fadd float %52, %53
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %55 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %54, i32 4, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %56 = fadd float %54, %55
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %57 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %56, i32 8, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %58 = fadd float %56, %57
# ; ││└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29 within `shfl_down_sync` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#      %59 = call float @llvm.nvvm.shfl.sync.down.f32(i32 -1, float %58, i32 16, i32 31)
# ; ││└
# ; ││┌ @ float.jl:398 within `+`
#      %60 = fadd float %58, %59
# ; └└└
# ; ┌ @ float.jl:398 within `+`
#    br label %L723
#
# L723:                                             ; preds = %L713, %L694
#    %value_phi27 = phi float [ %value_phi24, %L694 ], [ %60, %L713 ]
#    %61 = fadd float %value_phi11, %value_phi27
# ; └
# ; ┌ @ range.jl:832 within `iterate`
# ; │┌ @ promotion.jl:468 within `==`
#     %.not52 = icmp eq i64 %value_phi9, %88
# ; │└
#    %62 = add i64 %value_phi9, %107
# ; └
#   br i1 %.not52, label %L737, label %L276
#
# L737:                                             ; preds = %pass2, %L723
#   %value_phi31 = phi float [ 0.000000e+00, %pass2 ], [ %61, %L723 ]
# ;  @ In[95]:15 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:14 within `sync_threads`
#    call void @llvm.nvvm.barrier0()
# ; └
# ;  @ In[95]:18 within `rmse_kernel_opt`
# ; ┌ @ promotion.jl:468 within `==`
#    %.not53 = icmp eq i32 %77, 0
# ; └
#   br i1 %.not53, label %L751, label %L763
#
# L751:                                             ; preds = %L737
# ;  @ In[95]:19 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:438 within `macro expansion`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:443 within `atomic_arrayset` @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:455
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:77 within `pointer`
# ; │││┌ @ abstractarray.jl:1171 within `_memory_offset`
# ; ││││┌ @ int.jl:88 within `*`
#        %63 = shl nuw nsw i32 %5, 2
#        %64 = zext i32 %63 to i64
# ; │││└└
# ; │││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:110 within `+`
#       %65 = getelementptr i8, i8 addrspace(1)* %.fca.0.extract29, i64 %64
# ; ││└└
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:99 within `atomic_add!`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:28 within `llvm_atomic_op`
# ; ││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/atomics.jl:28 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#        %66 = bitcast i8 addrspace(1)* %65 to float addrspace(1)*
#        %67 = atomicrmw fadd float addrspace(1)* %66, float %value_phi31 acq_rel
#        br label %L763
#
# L763:                                             ; preds = %L751, %L737
# ; └└└└└
# ;  @ In[95]:21 within `rmse_kernel_opt`
#   ret void
#
# fail:                                             ; preds = %entry
# ;  @ In[95]:3 within `rmse_kernel_opt`
# ; ┌ @ abstractarray.jl:1218 within `getindex`
# ; │┌ @ abstractarray.jl:1257 within `_getindex`
# ; ││┌ @ abstractarray.jl:1264 within `_to_subscript_indices`
# ; │││┌ @ abstractarray.jl:1286 within `_unsafe_ind2sub`
# ; ││││┌ @ abstractarray.jl:2559 within `_ind2sub` @ abstractarray.jl:2597
# ; │││││┌ @ abstractarray.jl:2610 within `_ind2sub_recurse`
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception1 to i64))
#           call fastcc void @gpu_signal_exception([1 x i64] %state)
#           call void asm sideeffect "exit;", ""() #5
#           unreachable
#
# pass:                                             ; preds = %entry
#           %68 = udiv i64 %9, %.fca.0.0.0.extract
# ; │││││└└└
# ; │││││┌ @ abstractarray.jl:2611 within `_ind2sub_recurse`
# ; ││││││┌ @ int.jl:88 within `*`
#          %69 = mul i64 %68, %.fca.0.0.0.extract
# ; ││││││└
# ; ││││││┌ @ int.jl:86 within `-`
#          %70 = sub i64 %9, %69
# ; ││││││└
# ; ││││││┌ @ int.jl:87 within `+`
#          %71 = add i64 %70, 1
# ; ││││││└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2610
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           br i1 %7, label %pass2, label %fail1
#
# fail1:                                            ; preds = %pass
#           call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception1 to i64))
#           call fastcc void @gpu_signal_exception([1 x i64] %state)
#           call void asm sideeffect "exit;", ""() #5
#           unreachable
#
# pass2:                                            ; preds = %pass
#           %72 = udiv i64 %68, %.fca.0.1.0.extract
# ; ││││││└└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2611
# ; ││││││┌ @ int.jl:88 within `*`
#          %73 = mul i64 %72, %8
# ; ││││││└
# ; ││││││┌ @ int.jl:86 within `-`
#          %74 = sub i64 %68, %73
# ; ││││││└
# ; ││││││┌ @ int.jl:87 within `+`
#          %75 = add i64 %74, 1
# ; ││││││└
# ; ││││││ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2611 @ abstractarray.jl:2605
# ; ││││││┌ @ abstractarray.jl:2615 within `_lookup`
# ; │││││││┌ @ int.jl:87 within `+`
#           %76 = add nuw nsw i64 %72, 1
# ; └└└└└└└└
# ;  @ In[95]:7 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:92 within `#threadIdx`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:46 within `threadIdx_x`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `_index`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#       %77 = call i32 @llvm.nvvm.read.ptx.sreg.tid.x()
# ; ││└└
# ; ││┌ @ int.jl:87 within `+`
#      %78 = add nuw nsw i32 %77, 1
# ; └└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:78 within `#blockIdx`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:56 within `blockIdx_x`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `_index`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#       %79 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.x()
# ; └└└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:85 within `#blockDim`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:51 within `blockDim_x`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `_index`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#       %80 = call i32 @llvm.nvvm.read.ptx.sreg.ntid.x()
# ; └└└└
# ; ┌ @ int.jl:88 within `*`
#    %81 = mul i32 %80, %79
# ; └
# ; ┌ @ int.jl:87 within `+`
#    %82 = add i32 %78, %81
# ; └
# ;  @ In[95]:8 within `rmse_kernel_opt`
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:71 within `#gridDim`
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:61 within `gridDim_x`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `_index`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/indexing.jl:6 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#       %83 = call i32 @llvm.nvvm.read.ptx.sreg.nctaid.x()
# ; └└└└
# ; ┌ @ int.jl:88 within `*`
#    %84 = mul i32 %83, %80
# ; └
# ; ┌ @ multidimensional.jl:435 within `length`
# ; │┌ @ tuple.jl:499 within `prod`
# ; ││┌ @ operators.jl:655 within `*` @ int.jl:88
#      %85 = mul i64 %.fca.0.0.0.extract4, %.fca.0.1.0.extract6
#      %86 = mul i64 %85, %.fca.0.2.0.extract8
# ; └└└
# ; ┌ @ range.jl:10 within `Colon`
# ; │┌ @ number.jl:7 within `convert`
# ; ││┌ @ boot.jl:762 within `Int64`
# ; │││┌ @ boot.jl:681 within `toInt64`
#       %87 = sext i32 %82 to i64
# ; │└└└
# ; │ @ range.jl:10 within `Colon` @ range.jl:41
# ; │┌ @ range.jl:46 within `_colon`
# ; ││┌ @ range.jl:330 within `StepRange` @ range.jl:275
#      %88 = call fastcc i64 @julia_steprange_last_14036([1 x i64] %state, i64 %87, i32 %84, i64 %86)
# ; └└└
# ; ┌ @ range.jl:828 within `iterate`
# ; │┌ @ range.jl:606 within `isempty`
# ; ││┌ @ operators.jl:278 within `!=`
# ; │││┌ @ promotion.jl:468 within `==`
#       %89 = icmp ne i64 %88, %87
# ; ││└└
# ; ││┌ @ operators.jl:378 within `>`
# ; │││┌ @ int.jl:83 within `<`
#       %90 = icmp sgt i32 %84, 0
#       %91 = icmp sgt i64 %88, %87
# ; ││└└
# ; ││┌ @ operators.jl:278 within `!=`
# ; │││┌ @ bool.jl:35 within `!`
#       %92 = xor i1 %90, %91
# ; ││└└
# ; ││┌ @ bool.jl:38 within `&`
#      %93 = and i1 %89, %92
# ; └└└
#   br i1 %93, label %L737, label %L276.preheader
#
# L276.preheader:                                   ; preds = %pass2
#   %94 = icmp sgt i64 %.fca.0.0.0.extract4, 0
#   %95 = icmp sgt i64 %.fca.0.1.0.extract6, 0
#   %96 = select i1 %95, i64 %.fca.0.1.0.extract6, i64 0
#   %97 = icmp sgt i64 %.fca.2.0.extract19, 0
#   %98 = select i1 %97, i64 %.fca.2.0.extract19, i64 0
#   %99 = icmp sgt i64 %.fca.2.1.extract20, 0
#   %100 = select i1 %99, i64 %.fca.2.1.extract20, i64 0
#   %101 = bitcast i8 addrspace(1)* %.fca.0.extract17 to float addrspace(1)*
#   %102 = icmp sgt i64 %.fca.2.0.extract, 0
#   %103 = select i1 %102, i64 %.fca.2.0.extract, i64 0
#   %104 = icmp sgt i64 %.fca.2.1.extract, 0
#   %105 = select i1 %104, i64 %.fca.2.1.extract, i64 0
#   %106 = bitcast i8 addrspace(1)* %.fca.0.extract10 to float addrspace(1)*
#   %107 = sext i32 %84 to i64
# ;  @ In[95]:9 within `rmse_kernel_opt`
# ; ┌ @ abstractarray.jl:1218 within `getindex`
# ; │┌ @ abstractarray.jl:1257 within `_getindex`
# ; ││┌ @ abstractarray.jl:1264 within `_to_subscript_indices`
# ; │││┌ @ abstractarray.jl:1286 within `_unsafe_ind2sub`
# ; ││││┌ @ abstractarray.jl:2559 within `_ind2sub` @ abstractarray.jl:2597
# ; │││││┌ @ abstractarray.jl:2610 within `_ind2sub_recurse`
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           br i1 %94, label %L276.preheader.L276.preheader.split_crit_edge, label %fail12.split
#
# L276.preheader.L276.preheader.split_crit_edge:    ; preds = %L276.preheader
#           br i1 %95, label %L276.preheader.split.L276.preheader.split.split_crit_edge, label %fail14.split
#
# L276.preheader.split.L276.preheader.split.split_crit_edge: ; preds = %L276.preheader.L276.preheader.split_crit_edge
# ; └└└└└└└└
# ;  @ In[95] within `rmse_kernel_opt`
#   %108 = call i32 @llvm.nvvm.read.ptx.sreg.warpsize()
#   %109 = icmp eq i32 %108, 32
#   call void @llvm.assume(i1 %109)
#   %110 = lshr i32 %80, 5
#   %111 = and i32 %80, 992
#   %112 = icmp ne i32 %111, %80
#   %113 = zext i1 %112 to i32
#   %114 = add nuw nsw i32 %110, %113
#   %.not48.not = icmp ult i32 %77, %114
# ;  @ In[95]:9 within `rmse_kernel_opt`
# ; ┌ @ abstractarray.jl:1218 within `getindex`
# ; │┌ @ abstractarray.jl:1257 within `_getindex`
# ; ││┌ @ abstractarray.jl:1264 within `_to_subscript_indices`
# ; │││┌ @ abstractarray.jl:1286 within `_unsafe_ind2sub`
# ; ││││┌ @ abstractarray.jl:2559 within `_ind2sub` @ abstractarray.jl:2597
# ; │││││┌ @ abstractarray.jl:2610 within `_ind2sub_recurse`
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           br label %L276
#
# fail12.split:                                     ; preds = %L276.preheader
#           call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception1 to i64))
#           call fastcc void @gpu_signal_exception([1 x i64] %state)
#           call void asm sideeffect "exit;", ""() #5
#           unreachable
#
# fail14.split:                                     ; preds = %L276.preheader.L276.preheader.split_crit_edge
# ; │││││└└└
# ; │││││┌ @ abstractarray.jl:2611 within `_ind2sub_recurse` @ abstractarray.jl:2610
# ; ││││││┌ @ abstractarray.jl:2617 within `_div`
# ; │││││││┌ @ int.jl:284 within `div`
#           call fastcc void @gpu_report_exception(i64 ptrtoint ([10 x i8]* @exception1 to i64))
#           call fastcc void @gpu_signal_exception([1 x i64] %state)
#           call void asm sideeffect "exit;", ""() #5
#           unreachable
# ; └└└└└└└└
# }
# ; PTX CompilerJob of kernel broadcast_kernel(CUDA.CuKernelContext, CuDeviceVector{Float32, 1}, Base.Broadcast.Broadcasted{Nothing, Tuple{Base.OneTo{Int64}}, typeof(sqrt), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1}, Nothing, typeof(/), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Int64}}}}, Int64) for sm_75
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:56 within `broadcast_kernel`
# define ptx_kernel void @_Z28julia_broadcast_kernel_1413415CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_([1 x i64] %state, { i8 addrspace(1)*, i64, [1 x i64] } %0, { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, i64 signext %2) local_unnamed_addr #1 {
# entry:
#   %.fca.2.0.extract = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 2, 0
#   %.fca.0.0.0.0.2.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 2, 0
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:57 within `broadcast_kernel`
# ; ┌ @ range.jl:5 within `Colon`
# ; │┌ @ range.jl:354 within `UnitRange`
# ; ││┌ @ range.jl:359 within `unitrange_last`
#      %.inv = icmp sgt i64 %2, 0
#      %3 = select i1 %.inv, i64 %2, i64 0
# ; └└└
#   br i1 %.inv, label %L13.preheader, label %L77
#
# L13.preheader:                                    ; preds = %entry
#   %.fca.0.0.0.1.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 1
#   %.fca.0.0.0.0.1.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 1, 0
#   %.fca.0.0.0.0.0.0.extract = extractvalue { [1 x { { { { i8 addrspace(1)*, i64, [1 x i64] }, [1 x i8], [1 x i64] }, i64 } }], [1 x [1 x i64]] } %1, 0, 0, 0, 0, 0, 0
#   %.fca.0.extract = extractvalue { i8 addrspace(1)*, i64, [1 x i64] } %0, 0
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl within `broadcast_kernel`
#   %4 = call i32 @llvm.nvvm.read.ptx.sreg.tid.x()
#   %5 = add nuw nsw i32 %4, 1
#   %6 = call i32 @llvm.nvvm.read.ptx.sreg.ctaid.x()
#   %7 = zext i32 %6 to i64
#   %8 = call i32 @llvm.nvvm.read.ptx.sreg.ntid.x()
#   %9 = zext i32 %8 to i64
#   %10 = mul nuw nsw i64 %9, %7
#   %11 = zext i32 %5 to i64
#   %12 = add nuw nsw i64 %10, %11
#   %13 = call i32 @llvm.nvvm.read.ptx.sreg.nctaid.x()
#   %14 = mul i32 %8, %13
#   %15 = sext i32 %14 to i64
#   %16 = and i8 %.fca.0.0.0.0.1.0.extract, 1
#   %.not16 = icmp eq i8 %16, 0
#   %17 = bitcast i8 addrspace(1)* %.fca.0.0.0.0.0.0.extract to float addrspace(1)*
#   %18 = sitofp i64 %.fca.0.0.0.1.extract to float
#   %19 = bitcast i8 addrspace(1)* %.fca.0.extract to float addrspace(1)*
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:58 within `broadcast_kernel`
# ; ┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67 within `macro expansion`
#    br i1 %.not16, label %L13.preheader.split.us, label %L13
#
# L13.preheader.split.us:                           ; preds = %L13.preheader
#    %20 = add i64 %.fca.0.0.0.0.2.0.extract, -1
#    %21 = getelementptr inbounds float, float addrspace(1)* %17, i64 %20
#    br label %L13.us
#
# L13.us:                                           ; preds = %__nv_sqrtf.exit.us, %L13.preheader.split.us
#    %value_phi3.us = phi i64 [ %41, %__nv_sqrtf.exit.us ], [ 1, %L13.preheader.split.us ]
# ; └
# ; ┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:66 within `macro expansion`
# ; │┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:44 within `linear_index`
# ; ││┌ @ int.jl:86 within `-`
#      %22 = add nsw i64 %value_phi3.us, -1
# ; ││└
# ; ││┌ @ int.jl:982 within `*` @ int.jl:88
#      %23 = mul i64 %22, %15
# ; ││└
# ; ││┌ @ int.jl:87 within `+`
#      %24 = add i64 %12, %23
# ; └└└
# ; ┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67 within `macro expansion`
# ; │┌ @ operators.jl:378 within `>`
# ; ││┌ @ int.jl:83 within `<`
#      %.not.us = icmp slt i64 %.fca.2.0.extract, %24
# ; │└└
#    br i1 %.not.us, label %L77, label %L150.us
#
# L150.us:                                          ; preds = %L13.us
# ; └
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:59 within `broadcast_kernel`
# ; ┌ @ broadcast.jl:597 within `getindex`
# ; │┌ @ broadcast.jl:642 within `_broadcast_getindex`
# ; ││┌ @ broadcast.jl:667 within `_getindex`
# ; │││┌ @ broadcast.jl:642 within `_broadcast_getindex`
# ; ││││┌ @ broadcast.jl:666 within `_getindex`
# ; │││││┌ @ broadcast.jl:636 within `_broadcast_getindex`
# ; ││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:202
# ; │││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:121 within `arrayref`
# ; ││││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:129 within `arrayref_bits`
# ; │││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:81 within `unsafe_load`
# ; ││││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `pointerref`
# ; │││││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#               %25 = load float, float addrspace(1)* %21, align 4
# ; │││└└└└└└└└└
# ; │││┌ @ broadcast.jl:643 within `_broadcast_getindex`
# ; ││││┌ @ broadcast.jl:670 within `_broadcast_getindex_evalf`
# ; │││││┌ @ promotion.jl:382 within `/` @ float.jl:407
#         %26 = fdiv float %25, %18
# ; │└└└└└
# ; │┌ @ broadcast.jl:643 within `_broadcast_getindex`
# ; ││┌ @ broadcast.jl:670 within `_broadcast_getindex_evalf`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/math.jl:218 within `#sqrt`
#       %27 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([11 x i8], [11 x i8]* @.str, i64 0, i64 0)) #3
#       %.not.i.us = icmp eq i32 %27, 0
#       %28 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([17 x i8], [17 x i8]* @.str.2, i64 0, i64 0)) #3
#       %.not1.i.us = icmp eq i32 %28, 0
#       br i1 %.not.i.us, label %34, label %29
#
# 29:                                               ; preds = %L150.us
#       br i1 %.not1.i.us, label %32, label %30
#
# 30:                                               ; preds = %29
#       %31 = call float @llvm.nvvm.sqrt.rn.ftz.f(float %26) #3
#       br label %__nv_sqrtf.exit.us
#
# 32:                                               ; preds = %29
#       %33 = call float @llvm.nvvm.sqrt.approx.ftz.f(float %26) #3
#       br label %__nv_sqrtf.exit.us
#
# 34:                                               ; preds = %L150.us
#       br i1 %.not1.i.us, label %37, label %35
#
# 35:                                               ; preds = %34
#       %36 = call float @llvm.sqrt.f32(float %26) #3
#       br label %__nv_sqrtf.exit.us
#
# 37:                                               ; preds = %34
#       %38 = call float @llvm.nvvm.sqrt.approx.f(float %26) #3
#       br label %__nv_sqrtf.exit.us
#
# __nv_sqrtf.exit.us:                               ; preds = %37, %35, %32, %30
#       %.0.i.us = phi float [ %31, %30 ], [ %33, %32 ], [ %36, %35 ], [ %38, %37 ]
# ; └└└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:217 within `setindex!` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:204
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:163 within `arrayset`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:172 within `arrayset_bits`
# ; │││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:84 within `unsafe_store!`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `pointerset`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; ││││││┌ @ int.jl:86 within `-`
#          %39 = add i64 %24, -1
# ; ││││││└
#         %40 = getelementptr inbounds float, float addrspace(1)* %19, i64 %39
#         store float %.0.i.us, float addrspace(1)* %40, align 4
# ; └└└└└└
# ; ┌ @ range.jl:832 within `iterate`
# ; │┌ @ promotion.jl:468 within `==`
#     %.not17.us = icmp eq i64 %value_phi3.us, %3
# ; │└
#    %41 = add nuw i64 %value_phi3.us, 1
# ; └
#   br i1 %.not17.us, label %L77, label %L13.us
#
# L13:                                              ; preds = %__nv_sqrtf.exit, %L13.preheader
#   %value_phi3 = phi i64 [ %62, %__nv_sqrtf.exit ], [ 1, %L13.preheader ]
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:58 within `broadcast_kernel`
# ; ┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:66 within `macro expansion`
# ; │┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:44 within `linear_index`
# ; ││┌ @ int.jl:86 within `-`
#      %42 = add nsw i64 %value_phi3, -1
# ; ││└
# ; ││┌ @ int.jl:982 within `*` @ int.jl:88
#      %43 = mul i64 %42, %15
# ; ││└
# ; ││┌ @ int.jl:87 within `+`
#      %44 = add i64 %12, %43
# ; └└└
# ; ┌ @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67 within `macro expansion`
# ; │┌ @ operators.jl:378 within `>`
# ; ││┌ @ int.jl:83 within `<`
#      %.not = icmp slt i64 %.fca.2.0.extract, %44
# ; │└└
#    br i1 %.not, label %L77, label %L150
#
# L77:                                              ; preds = %__nv_sqrtf.exit, %L13, %__nv_sqrtf.exit.us, %L13.us, %entry
#    ret void
#
# L150:                                             ; preds = %L13
# ; └
# ;  @ /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:59 within `broadcast_kernel`
# ; ┌ @ broadcast.jl:597 within `getindex`
# ; │┌ @ broadcast.jl:642 within `_broadcast_getindex`
# ; ││┌ @ broadcast.jl:667 within `_getindex`
# ; │││┌ @ broadcast.jl:642 within `_broadcast_getindex`
# ; ││││┌ @ broadcast.jl:666 within `_getindex`
# ; │││││┌ @ broadcast.jl:636 within `_broadcast_getindex`
# ; ││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:214 within `getindex` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:202
# ; │││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:121 within `arrayref`
# ; ││││││││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:129 within `arrayref_bits`
# ; │││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:81 within `unsafe_load`
# ; ││││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `pointerref`
# ; │││││││││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:9 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
# ; ││││││││││││┌ @ int.jl:86 within `-`
#                %45 = add i64 %44, -1
# ; ││││││││││││└
#               %46 = getelementptr inbounds float, float addrspace(1)* %17, i64 %45
#               %47 = load float, float addrspace(1)* %46, align 4
# ; │││└└└└└└└└└
# ; │││┌ @ broadcast.jl:643 within `_broadcast_getindex`
# ; ││││┌ @ broadcast.jl:670 within `_broadcast_getindex_evalf`
# ; │││││┌ @ promotion.jl:382 within `/` @ float.jl:407
#         %48 = fdiv float %47, %18
# ; │└└└└└
# ; │┌ @ broadcast.jl:643 within `_broadcast_getindex`
# ; ││┌ @ broadcast.jl:670 within `_broadcast_getindex_evalf`
# ; │││┌ @ /home/tim/Julia/pkg/CUDA/src/device/intrinsics/math.jl:218 within `#sqrt`
#       %49 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([11 x i8], [11 x i8]* @.str, i64 0, i64 0)) #3
#       %.not.i = icmp eq i32 %49, 0
#       %50 = call i32 @__nvvm_reflect(i8* getelementptr inbounds ([17 x i8], [17 x i8]* @.str.2, i64 0, i64 0)) #3
#       %.not1.i = icmp eq i32 %50, 0
#       br i1 %.not.i, label %56, label %51
#
# 51:                                               ; preds = %L150
#       br i1 %.not1.i, label %54, label %52
#
# 52:                                               ; preds = %51
#       %53 = call float @llvm.nvvm.sqrt.rn.ftz.f(float %48) #3
#       br label %__nv_sqrtf.exit
#
# 54:                                               ; preds = %51
#       %55 = call float @llvm.nvvm.sqrt.approx.ftz.f(float %48) #3
#       br label %__nv_sqrtf.exit
#
# 56:                                               ; preds = %L150
#       br i1 %.not1.i, label %59, label %57
#
# 57:                                               ; preds = %56
#       %58 = call float @llvm.sqrt.f32(float %48) #3
#       br label %__nv_sqrtf.exit
#
# 59:                                               ; preds = %56
#       %60 = call float @llvm.nvvm.sqrt.approx.f(float %48) #3
#       br label %__nv_sqrtf.exit
#
# __nv_sqrtf.exit:                                  ; preds = %59, %57, %54, %52
#       %.0.i = phi float [ %53, %52 ], [ %55, %54 ], [ %58, %57 ], [ %60, %59 ]
# ; └└└└
# ; ┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:217 within `setindex!` @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:204
# ; │┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:163 within `arrayset`
# ; ││┌ @ /home/tim/Julia/pkg/CUDA/src/device/array.jl:172 within `arrayset_bits`
# ; │││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:84 within `unsafe_store!`
# ; ││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `pointerset`
# ; │││││┌ @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/pointer.jl:44 within `macro expansion` @ /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         %61 = getelementptr inbounds float, float addrspace(1)* %19, i64 %45
#         store float %.0.i, float addrspace(1)* %61, align 4
# ; └└└└└└
# ; ┌ @ range.jl:832 within `iterate`
# ; │┌ @ promotion.jl:468 within `==`
#     %.not17 = icmp eq i64 %value_phi3, %3
# ; │└
#    %62 = add nuw i64 %value_phi3, 1
# ; └
#   br i1 %.not17, label %L77, label %L13
# }

# %% [markdown]
# We cannot simplify avoid this exception using an `@inbounds`-like macro, or by using differently-typed indices. However, if we look at the definition of `div` we can see that the exception is thrown when the divisor is 0. Here, the divisor is the size of the abstract array being indexed, and we can tell LLVM it can never be 0 using the `assume` intrinsic:

# %%
using LLVM, LLVM.Interop
function rmse_kernel_opt(C::AbstractArray{T}, A, B, Rmain, Rbatch) where T
    batch = blockIdx().y
    assume.(size(Rbatch) .> 0)
    Ibatch = @inbounds Rbatch[batch]
    
    # grid-stride loop to process each batch in a block
    val = zero(T)
    i0 = threadIdx().x + (blockIdx().x-Int32(1))*blockDim().x
    assume.(size(Rmain) .> 0)
    @inbounds for i in i0:(blockDim().x*gridDim().x):length(Rmain)
        Imain = Rmain[i]
        I = max(Imain, Ibatch)
        a = A[I]
        b = B[I]
        val += CUDA.reduce_block(+, (a-b)^2, zero(T), #=shuffle=# Val(true))
    end    
    sync_threads()
    
    # finalize the computation
    if threadIdx().x == Int32(1)
        @inbounds CUDA.@atomic C[batch] += val
    end
    return
end;

# %%
kernel = @cuda launch=false rmse_kernel_opt(C, A, B, CartesianIndices(axes(A)), CartesianIndices(axes(A)))
CUDA.registers(kernel)
# Out:
# 82

# %%
@device_code_ptx rmse_opt(C,A,B)
# Out:
# // PTX CompilerJob of kernel rmse_kernel_opt(CuDeviceVector{Float32, 1}, CuDeviceArray{Float32, 3, 1}, CuDeviceArray{Float32, 3, 1}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}) for sm_75
#
# //
# // Generated by LLVM NVPTX Back-End
# //
#
# .version 6.3
# .target sm_75
# .address_size 64
#
# 	// .globl	_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE // -- Begin function _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE
# .extern .func  (.param .b64 func_retval0) julia_steprange_last_14439
# (
# 	.param .align 8 .b8 julia_steprange_last_14439_param_0[8],
# 	.param .b64 julia_steprange_last_14439_param_1,
# 	.param .b32 julia_steprange_last_14439_param_2,
# 	.param .b64 julia_steprange_last_14439_param_3
# )
# ;
# .extern .func  (.param .align 4 .b8 func_retval0[8]) julia_fldmod1_14437
# (
# 	.param .align 8 .b8 julia_fldmod1_14437_param_0[8],
# 	.param .b32 julia_fldmod1_14437_param_1,
# 	.param .b32 julia_fldmod1_14437_param_2
# )
# ;
# // shmem has been demoted
#                                         // @_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE
# .visible .entry _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE(
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_0[8],
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_1[24],
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_2[40],
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_3[40],
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_4[24],
# 	.param .align 8 .b8 _Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_5[24]
# )
# {
# 	.reg .pred 	%p<19>;
# 	.reg .f32 	%f<39>;
# 	.reg .b32 	%r<35>;
# 	.reg .b64 	%rd<98>;
# 	// demoted variable
# 	.shared .align 32 .b8 shmem[128];
# // %bb.0:                               // %entry
# 	ld.param.u64 	%rd10, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_5+8];
# 	ld.param.u64 	%rd9, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_5];
# 	mov.u32 	%r8, %ctaid.y;
# 	cvt.u64.u32 	%rd11, %r8;
# 	setp.lt.u64 	%p1, %rd11, %rd9;
# 	mov.u64 	%rd94, 0;
# 	cvt.u32.u64 	%r34, %rd11;
# 	mov.u64 	%rd93, %rd94;
# 	@%p1 bra 	LBB0_2;
# // %bb.1:
# 	cvt.u32.u64 	%r9, %rd9;
# 	div.u32 	%r11, %r34, %r9;
# 	cvt.u64.u32 	%rd93, %r11;
# LBB0_2:
# 	ld.param.u64 	%rd46, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_0];
# 	ld.param.u64 	%rd6, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_4];
# 	ld.param.u64 	%rd7, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_4+8];
# 	ld.param.u64 	%rd8, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_4+16];
# 	setp.lt.u64 	%p2, %rd93, %rd10;
# 	@%p2 bra 	LBB0_4;
# // %bb.3:
# 	cvt.u32.u64 	%r12, %rd10;
# 	cvt.u32.u64 	%r13, %rd93;
# 	div.u32 	%r14, %r13, %r12;
# 	cvt.u64.u32 	%rd94, %r14;
# LBB0_4:
# 	mov.u32 	%r1, %tid.x;
# 	add.s32 	%r2, %r1, 1;
# 	mov.u32 	%r15, %ctaid.x;
# 	mov.u32 	%r3, %ntid.x;
# 	mad.lo.s32 	%r16, %r3, %r15, %r2;
# 	mov.u32 	%r17, %nctaid.x;
# 	mul.lo.s32 	%r4, %r17, %r3;
# 	mul.lo.s64 	%rd61, %rd6, %rd7;
# 	mul.lo.s64 	%rd62, %rd61, %rd8;
# 	cvt.s64.s32 	%rd95, %r16;
# 	{ // callseq 634, 0
# 	.reg .b32 temp_param_reg;
# 	.param .align 8 .b8 param0[8];
# 	st.param.b64 	[param0+0], %rd46;
# 	.param .b64 param1;
# 	st.param.b64 	[param1+0], %rd95;
# 	.param .b32 param2;
# 	st.param.b32 	[param2+0], %r4;
# 	.param .b64 param3;
# 	st.param.b64 	[param3+0], %rd62;
# 	.param .b64 retval0;
# 	call.uni (retval0),
# 	julia_steprange_last_14439,
# 	(
# 	param0,
# 	param1,
# 	param2,
# 	param3
# 	);
# 	ld.param.b64 	%rd63, [retval0+0];
# 	} // callseq 634
# 	setp.ne.s64 	%p3, %rd63, %rd95;
# 	setp.gt.s32 	%p4, %r4, 0;
# 	setp.gt.s64 	%p5, %rd63, %rd95;
# 	xor.pred  	%p6, %p4, %p5;
# 	and.pred  	%p7, %p3, %p6;
# 	mov.f32 	%f38, 0f00000000;
# 	@%p7 bra 	LBB0_19;
# 	bra.uni 	LBB0_5;
# LBB0_19:                                // %L835
# 	bar.sync 	0;
# 	setp.ne.s32 	%p18, %r1, 0;
# 	@%p18 bra 	LBB0_21;
# // %bb.20:                              // %L849
# 	ld.param.u64 	%rd1, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_1];
# 	shl.b32 	%r33, %r34, 2;
# 	cvt.u64.u32 	%rd92, %r33;
# 	add.s64 	%rd45, %rd1, %rd92;
# 	atom.global.add.f32 	%f34, [%rd45], %f38;
# LBB0_21:                                // %L861
# 	ret;
# LBB0_5:                                 // %L374.preheader
# 	mul.lo.s64 	%rd59, %rd93, %rd9;
# 	sub.s64 	%rd14, %rd11, %rd59;
# 	ld.param.u64 	%rd55, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_3+24];
# 	ld.param.u64 	%rd54, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_3+16];
# 	ld.param.u64 	%rd52, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_3];
# 	ld.param.u64 	%rd50, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_2+24];
# 	ld.param.u64 	%rd49, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_2+16];
# 	ld.param.u64 	%rd47, [_Z27julia_rmse_kernel_opt_1434913CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE_param_2];
# 	add.s64 	%rd15, %rd14, 1;
# 	mul.lo.s64 	%rd60, %rd94, %rd10;
# 	sub.s64 	%rd18, %rd93, %rd60;
# 	add.s64 	%rd19, %rd18, 1;
# 	add.s64 	%rd20, %rd94, 1;
# 	max.s64 	%rd25, %rd49, 0;
# 	max.s64 	%rd26, %rd50, 0;
# 	max.s64 	%rd27, %rd54, 0;
# 	max.s64 	%rd28, %rd55, 0;
# 	cvt.s64.s32 	%rd29, %r4;
# 	shr.u32 	%r18, %r3, 5;
# 	and.b32  	%r19, %r3, 992;
# 	setp.ne.s32 	%p8, %r19, %r3;
# 	selp.u32 	%r20, 1, 0, %p8;
# 	add.s32 	%r5, %r18, %r20;
# 	add.s64 	%rd30, %rd63, %rd29;
# 	neg.s64 	%rd31, %rd6;
# 	mov.f32 	%f38, 0f00000000;
# 	setp.ge.u32 	%p15, %r1, %r5;
# 	bra.uni 	LBB0_6;
# LBB0_18:                                // %L821
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	add.rn.f32 	%f38, %f38, %f37;
# 	add.s64 	%rd95, %rd95, %rd29;
# 	setp.ne.s64 	%p17, %rd30, %rd95;
# 	@%p17 bra 	LBB0_6;
# 	bra.uni 	LBB0_19;
# LBB0_6:                                 // %L374
#                                         // =>This Inner Loop Header: Depth=1
# 	add.s64 	%rd33, %rd95, -1;
# 	or.b64  	%rd64, %rd33, %rd6;
# 	and.b64  	%rd65, %rd64, -4294967296;
# 	setp.ne.s64 	%p9, %rd65, 0;
# 	@%p9 bra 	LBB0_8;
# 	bra.uni 	LBB0_7;
# LBB0_8:                                 //   in Loop: Header=BB0_6 Depth=1
# 	div.s64 	%rd96, %rd33, %rd6;
# 	bra.uni 	LBB0_9;
# LBB0_7:                                 //   in Loop: Header=BB0_6 Depth=1
# 	cvt.u32.u64 	%r21, %rd6;
# 	cvt.u32.u64 	%r22, %rd33;
# 	div.u32 	%r23, %r22, %r21;
# 	cvt.u64.u32 	%rd96, %r23;
# LBB0_9:                                 //   in Loop: Header=BB0_6 Depth=1
# 	mul.lo.s64 	%rd66, %rd31, %rd96;
# 	add.s64 	%rd37, %rd95, %rd66;
# 	add.s64 	%rd38, %rd37, -1;
# 	or.b64  	%rd67, %rd96, %rd7;
# 	and.b64  	%rd68, %rd67, -4294967296;
# 	setp.ne.s64 	%p10, %rd68, 0;
# 	@%p10 bra 	LBB0_11;
# 	bra.uni 	LBB0_10;
# LBB0_11:                                //   in Loop: Header=BB0_6 Depth=1
# 	div.s64 	%rd97, %rd96, %rd7;
# 	bra.uni 	LBB0_12;
# LBB0_10:                                //   in Loop: Header=BB0_6 Depth=1
# 	cvt.u32.u64 	%r24, %rd7;
# 	cvt.u32.u64 	%r25, %rd96;
# 	div.u32 	%r26, %r25, %r24;
# 	cvt.u64.u32 	%rd97, %r26;
# LBB0_12:                                //   in Loop: Header=BB0_6 Depth=1
# 	mul.lo.s64 	%rd69, %rd97, %rd7;
# 	sub.s64 	%rd70, %rd96, %rd69;
# 	add.s64 	%rd71, %rd70, 1;
# 	add.s64 	%rd72, %rd97, 1;
# 	setp.lt.s64 	%p11, %rd15, %rd37;
# 	setp.lt.s64 	%p12, %rd19, %rd71;
# 	setp.lt.s64 	%p13, %rd20, %rd72;
# 	selp.b64 	%rd73, %rd70, %rd18, %p12;
# 	selp.b64 	%rd74, %rd97, %rd94, %p13;
# 	mul.lo.s64 	%rd75, %rd74, %rd26;
# 	add.s64 	%rd76, %rd73, %rd75;
# 	mul.lo.s64 	%rd77, %rd76, %rd25;
# 	selp.b64 	%rd78, %rd38, %rd14, %p11;
# 	add.s64 	%rd79, %rd78, %rd77;
# 	shl.b64 	%rd80, %rd79, 2;
# 	add.s64 	%rd81, %rd47, %rd80;
# 	ld.global.f32 	%f11, [%rd81];
# 	mul.lo.s64 	%rd82, %rd74, %rd28;
# 	add.s64 	%rd83, %rd73, %rd82;
# 	mul.lo.s64 	%rd84, %rd83, %rd27;
# 	add.s64 	%rd85, %rd78, %rd84;
# 	shl.b64 	%rd86, %rd85, 2;
# 	add.s64 	%rd87, %rd52, %rd86;
# 	ld.global.f32 	%f12, [%rd87];
# 	sub.rn.f32 	%f13, %f11, %f12;
# 	mov.u32 	%r27, 32;
# 	{ // callseq 635, 0
# 	.reg .b32 temp_param_reg;
# 	.param .align 8 .b8 param0[8];
# 	st.param.b64 	[param0+0], %rd46;
# 	.param .b32 param1;
# 	st.param.b32 	[param1+0], %r2;
# 	.param .b32 param2;
# 	st.param.b32 	[param2+0], %r27;
# 	.param .align 4 .b8 retval0[8];
# 	call.uni (retval0),
# 	julia_fldmod1_14437,
# 	(
# 	param0,
# 	param1,
# 	param2
# 	);
# 	ld.param.b32 	%r28, [retval0+0];
# 	ld.param.b32 	%r29, [retval0+4];
# 	} // callseq 635
# 	mul.rn.f32 	%f14, %f13, %f13;
# 	shfl.sync.down.b32	%f15, %f14, 1, 31, -1;
# 	add.rn.f32 	%f16, %f14, %f15;
# 	shfl.sync.down.b32	%f17, %f16, 2, 31, -1;
# 	add.rn.f32 	%f18, %f16, %f17;
# 	shfl.sync.down.b32	%f19, %f18, 4, 31, -1;
# 	add.rn.f32 	%f20, %f18, %f19;
# 	shfl.sync.down.b32	%f21, %f20, 8, 31, -1;
# 	add.rn.f32 	%f22, %f20, %f21;
# 	shfl.sync.down.b32	%f23, %f22, 16, 31, -1;
# 	setp.ne.s32 	%p14, %r29, 1;
# 	mov.u64 	%rd89, shmem;
# 	@%p14 bra 	LBB0_14;
# // %bb.13:                              // %L725
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	add.rn.f32 	%f2, %f22, %f23;
# 	add.s32 	%r30, %r28, -1;
# 	mul.wide.s32 	%rd88, %r30, 4;
# 	add.s64 	%rd42, %rd89, %rd88;
# 	st.shared.f32 	[%rd42], %f2;
# LBB0_14:                                // %L733
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	bar.sync 	0;
# 	mov.f32 	%f37, 0f00000000;
# 	@%p15 bra 	LBB0_16;
# // %bb.15:                              // %L783
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	add.s32 	%r31, %r29, -1;
# 	mul.wide.s32 	%rd90, %r31, 4;
# 	add.s64 	%rd43, %rd89, %rd90;
# 	ld.shared.f32 	%f37, [%rd43];
# LBB0_16:                                // %L792
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	setp.ne.s32 	%p16, %r28, 1;
# 	@%p16 bra 	LBB0_18;
# // %bb.17:                              // %L811
#                                         //   in Loop: Header=BB0_6 Depth=1
# 	shfl.sync.down.b32	%f25, %f37, 1, 31, -1;
# 	add.rn.f32 	%f26, %f37, %f25;
# 	shfl.sync.down.b32	%f27, %f26, 2, 31, -1;
# 	add.rn.f32 	%f28, %f26, %f27;
# 	shfl.sync.down.b32	%f29, %f28, 4, 31, -1;
# 	add.rn.f32 	%f30, %f28, %f29;
# 	shfl.sync.down.b32	%f31, %f30, 8, 31, -1;
# 	add.rn.f32 	%f32, %f30, %f31;
# 	shfl.sync.down.b32	%f33, %f32, 16, 31, -1;
# 	add.rn.f32 	%f37, %f32, %f33;
# 	bra.uni 	LBB0_18;
#                                         // -- End function
# }
# // PTX CompilerJob of kernel broadcast_kernel(CUDA.CuKernelContext, CuDeviceVector{Float32, 1}, Base.Broadcast.Broadcasted{Nothing, Tuple{Base.OneTo{Int64}}, typeof(sqrt), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1}, Nothing, typeof(/), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Int64}}}}, Int64) for sm_75
#
# //
# // Generated by LLVM NVPTX Back-End
# //
#
# .version 6.3
# .target sm_75
# .address_size 64
#
# 	// .globl	_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_ // -- Begin function _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_
# .global .align 1 .b8 _$_str[11] = {95, 95, 67, 85, 68, 65, 95, 70, 84, 90, 0};
# .global .align 1 .b8 _$_str_$_2[17] = {95, 95, 67, 85, 68, 65, 95, 80, 82, 69, 67, 95, 83, 81, 82, 84, 0};
#                                         // @_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_
# .visible .entry _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_(
# 	.param .align 8 .b8 _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_0[8],
# 	.param .align 8 .b8 _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_1[24],
# 	.param .align 8 .b8 _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_2[56],
# 	.param .u64 _Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_3
# )
# {
# 	.reg .pred 	%p<11>;
# 	.reg .b16 	%rs<3>;
# 	.reg .f32 	%f<8>;
# 	.reg .b32 	%r<7>;
# 	.reg .b64 	%rd<58>;
#
# // %bb.0:                               // %entry
# 	ld.param.u64 	%rd39, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_3];
# 	setp.lt.s64 	%p1, %rd39, 1;
# 	@%p1 bra 	LBB0_8;
# // %bb.1:                               // %L13.preheader
# 	ld.param.u64 	%rd37, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_2+40];
# 	ld.param.u8 	%rs1, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_2+24];
# 	ld.param.u64 	%rd33, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_2];
# 	ld.param.u64 	%rd32, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_1+16];
# 	ld.param.u64 	%rd30, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_1];
# 	setp.gt.s64 	%p2, %rd39, 0;
# 	selp.b64 	%rd57, %rd39, 0, %p2;
# 	mov.u32 	%r1, %tid.x;
# 	add.s32 	%r2, %r1, 1;
# 	mov.u32 	%r3, %ctaid.x;
# 	cvt.u64.u32 	%rd6, %r3;
# 	mov.u32 	%r4, %ntid.x;
# 	cvt.u64.u32 	%rd7, %r4;
# 	cvt.u64.u32 	%rd8, %r2;
# 	mov.u32 	%r5, %nctaid.x;
# 	mul.lo.s32 	%r6, %r4, %r5;
# 	cvt.s64.s32 	%rd9, %r6;
# 	and.b16  	%rs2, %rs1, 1;
# 	setp.eq.b16 	%p3, %rs2, 1;
# 	mov.pred 	%p4, 0;
# 	xor.pred  	%p5, %p3, %p4;
# 	not.pred 	%p6, %p5;
# 	cvt.rn.f32.s64 	%f1, %rd37;
# 	@%p6 bra 	LBB0_3;
# 	bra.uni 	LBB0_2;
# LBB0_3:                                 // %L13.preheader.split.us
# 	ld.param.u64 	%rd36, [_Z28julia_broadcast_kernel_1454315CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5__param_2+32];
# 	shl.b64 	%rd46, %rd36, 2;
# 	add.s64 	%rd13, %rd33, %rd46;
# 	mul.lo.s64 	%rd47, %rd7, %rd6;
# 	add.s64 	%rd48, %rd8, %rd47;
# 	add.s64 	%rd49, %rd48, -1;
# 	shl.b64 	%rd50, %rd49, 2;
# 	add.s64 	%rd53, %rd30, %rd50;
# 	shl.b64 	%rd15, %rd9, 2;
# 	sub.s64 	%rd51, %rd49, %rd9;
# 	add.s64 	%rd52, %rd51, 1;
# LBB0_4:                                 // %L13.us
#                                         // =>This Inner Loop Header: Depth=1
# 	add.s64 	%rd52, %rd52, %rd9;
# 	setp.lt.s64 	%p9, %rd32, %rd52;
# 	@%p9 bra 	LBB0_8;
# // %bb.5:                               // %L150.us
#                                         //   in Loop: Header=BB0_4 Depth=1
# 	add.s64 	%rd57, %rd57, -1;
# 	add.s64 	%rd21, %rd53, %rd15;
# 	ld.global.f32 	%f5, [%rd13+-4];
# 	div.rn.f32 	%f6, %f5, %f1;
# 	sqrt.approx.f32 	%f7, %f6;
# 	st.global.f32 	[%rd53], %f7;
# 	setp.eq.s64 	%p10, %rd57, 0;
# 	mov.u64 	%rd53, %rd21;
# 	@%p10 bra 	LBB0_8;
# 	bra.uni 	LBB0_4;
# LBB0_2:                                 // %L13.preheader3
# 	mul.lo.s64 	%rd40, %rd7, %rd6;
# 	add.s64 	%rd41, %rd8, %rd40;
# 	add.s64 	%rd42, %rd41, -1;
# 	shl.b64 	%rd56, %rd42, 2;
# 	shl.b64 	%rd11, %rd9, 2;
# 	sub.s64 	%rd43, %rd42, %rd9;
# 	add.s64 	%rd55, %rd43, 1;
# LBB0_7:                                 // %L13
#                                         // =>This Inner Loop Header: Depth=1
# 	add.s64 	%rd55, %rd55, %rd9;
# 	setp.ge.s64 	%p7, %rd32, %rd55;
# 	@%p7 bra 	LBB0_6;
# 	bra.uni 	LBB0_8;
# LBB0_6:                                 // %L150
#                                         //   in Loop: Header=BB0_7 Depth=1
# 	add.s64 	%rd57, %rd57, -1;
# 	add.s64 	%rd28, %rd56, %rd11;
# 	add.s64 	%rd44, %rd33, %rd56;
# 	ld.global.f32 	%f2, [%rd44];
# 	div.rn.f32 	%f3, %f2, %f1;
# 	sqrt.approx.f32 	%f4, %f3;
# 	add.s64 	%rd45, %rd30, %rd56;
# 	st.global.f32 	[%rd45], %f4;
# 	setp.eq.s64 	%p8, %rd57, 0;
# 	mov.u64 	%rd56, %rd28;
# 	@%p8 bra 	LBB0_8;
# 	bra.uni 	LBB0_7;
# LBB0_8:                                 // %L77
# 	ret;
#                                         // -- End function
# }

# %%
@device_code_sass rmse_opt(C,A,B)
# Out:
# // PTX CompilerJob of kernel rmse_kernel_opt(CuDeviceVector{Float32, 1}, CuDeviceArray{Float32, 3, 1}, CuDeviceArray{Float32, 3, 1}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}, CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}) for sm_75
#
# 	.headerflags	@"EF_CUDA_TEXMODE_UNIFIED EF_CUDA_64BIT_ADDRESS EF_CUDA_SM75 EF_CUDA_VIRTUAL_SM(EF_CUDA_SM75)"
# 	.elftype	@"ET_EXEC"
#
#
# //--------------------- .text._Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE --------------------------
# 	.section	.text._Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE,"ax",@progbits
# 	.sectionflags	@"SHF_BARRIERS=1"
# 	.sectioninfo	@"SHI_REGISTERS=82"
# 	.align	128
#         .global         _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE
#         .type           _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE,@function
#         .size           _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE,(.L_127 - _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE)
#         .other          _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE,@"STO_CUDA_ENTRY STV_DEFAULT"
# _Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE:
#
# .text._Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE:
# ; Location ./In[98]:2
#         IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         S2R R76, SR_CTAID.Y ;
#         IADD3 R1, R1, -0x8, RZ ;
# ; Location ./int.jl:284
#         CS2R R78, SRZ ;
#         CS2R R18, SRZ ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         S2R R55, SR_TID.X ;
#         S2R R5, SR_CTAID.X ;
# ; Location ./int.jl:284
#         ISETP.GE.U32.AND P0, PT, R76, c[0x0][0x1e8], PT ;
#         ISETP.GE.U32.AND.EX P0, PT, RZ, c[0x0][0x1ec], PT, P0 ;
#    @!P0 BRA `(.L_6) ;
#         I2F.U32.RP R0, c[0x0][0x1e8] ;
#         ISETP.NE.U32.AND P2, PT, RZ, c[0x0][0x1e8], PT ;
#         IMAD.MOV.U32 R19, RZ, RZ, RZ ;
#         MUFU.RCP R0, R0 ;
#         IADD3 R2, R0, 0xffffffe, RZ ;
#         F2I.FTZ.U32.TRUNC.NTZ R3, R2 ;
#         IMAD.MOV.U32 R2, RZ, RZ, RZ ;
#         IMAD.MOV R7, RZ, RZ, -R3 ;
#         IMAD R7, R7, c[0x0][0x1e8], RZ ;
#         IMAD.HI.U32 R3, R3, R7, R2 ;
#         IMAD.HI.U32 R18, R3, R76, RZ ;
#         IMAD.MOV R3, RZ, RZ, -R18 ;
#         IMAD R3, R3, c[0x0][0x1e8], R76 ;
#         ISETP.GE.U32.AND P0, PT, R3, c[0x0][0x1e8], PT ;
#     @P0 IADD3 R3, R3, -c[0x0][0x1e8], RZ ;
#     @P0 IADD3 R18, R18, 0x1, RZ ;
#         ISETP.GE.U32.AND P1, PT, R3, c[0x0][0x1e8], PT ;
#     @P1 IADD3 R18, R18, 0x1, RZ ;
#    @!P2 LOP3.LUT R18, RZ, c[0x0][0x1e8], RZ, 0x33, !PT ;
#
# .L_6:
#         ISETP.GE.U32.AND P0, PT, R18, c[0x0][0x1f0], PT ;
#         ISETP.GE.U32.AND.EX P0, PT, R19, c[0x0][0x1f4], PT, P0 ;
#    @!P0 BRA `(.L_7) ;
#         I2F.U32.RP R0, c[0x0][0x1f0] ;
#         ISETP.NE.U32.AND P2, PT, RZ, c[0x0][0x1f0], PT ;
#         IMAD.MOV.U32 R79, RZ, RZ, RZ ;
#         MUFU.RCP R0, R0 ;
#         IADD3 R2, R0, 0xffffffe, RZ ;
#         F2I.FTZ.U32.TRUNC.NTZ R3, R2 ;
#         MOV R2, RZ ;
#         IMAD.MOV R7, RZ, RZ, -R3 ;
#         IMAD R7, R7, c[0x0][0x1f0], RZ ;
#         IMAD.HI.U32 R3, R3, R7, R2 ;
#         IMAD.HI.U32 R78, R3, R18, RZ ;
#         IMAD.MOV R3, RZ, RZ, -R78 ;
#         IMAD R3, R3, c[0x0][0x1f0], R18 ;
#         ISETP.GE.U32.AND P0, PT, R3, c[0x0][0x1f0], PT ;
#     @P0 IADD3 R3, R3, -c[0x0][0x1f0], RZ ;
#     @P0 IADD3 R78, R78, 0x1, RZ ;
#         ISETP.GE.U32.AND P1, PT, R3, c[0x0][0x1f0], PT ;
#     @P1 IADD3 R78, R78, 0x1, RZ ;
#    @!P2 LOP3.LUT R78, RZ, c[0x0][0x1f0], RZ, 0x33, !PT ;
#
# .L_7:
# ; Location ./int.jl:88
#         ULDC.64 UR6, c[0x0][0x1d8] ;
# ; Location ./int.jl:87
#         IADD3 R62, R55, 0x1, RZ ;
# ; Location ./int.jl:88
#         ULDC.64 UR8, c[0x0][0x1d0] ;
#         IMAD.MOV.U32 R61, RZ, RZ, c[0x0][0xc] ;
#         UIMAD.WIDE.U32 UR4, UR6, UR8, URZ ;
# ; Location ./range.jl:275
#         BMOV.32.CLEAR RZ, B8 ;
# ; Location ./int.jl:88
#         UIMAD UR6, UR6, UR9, URZ ;
# ; Location ./int.jl:87
#         IMAD R28, R5, c[0x0][0x0], R62 ;
# ; Location ./int.jl:88
#         ULDC UR8, c[0x0][0x1d0] ;
# ; Location ./range.jl:275
#         BSSY B8, `(.L_8) ;
# ; Location ./int.jl:88
#         UIMAD UR6, UR8, UR7, UR6 ;
#         IMAD R61, R61, c[0x0][0x0], RZ ;
# ; Location ./boot.jl:681
#         SHF.R.S32.HI R29, RZ, 0x1f, R28 ;
# ; Location ./int.jl:88
#         UIADD3 UR5, UR5, UR6, URZ ;
# ; Location ./range.jl:275
#         MOV R2, 0x480 ;
# ; Location ./int.jl:88
#         ULDC.64 UR6, c[0x0][0x1e0] ;
#         UIMAD UR5, UR5, UR6, URZ ;
#         UIMAD.WIDE.U32 UR36, UR4, UR6, URZ ;
#         UIMAD UR5, UR4, UR7, UR5 ;
#         UIADD3 UR38, UR37, UR5, URZ ;
# ; Location ./range.jl:275
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_steprange_last_14752) ;
#         BSYNC B8 ;
#
# .L_8:
# ; Location ./int.jl:83
#         ISETP.GT.U32.AND P0, PT, R17.reuse, R28.reuse, PT ;
# ; Location ./bool.jl:38
#         IMAD.MOV.U32 R60, RZ, RZ, RZ ;
#         ISETP.NE.U32.AND P1, PT, R17, R28, PT ;
# ; Location ./int.jl:83
#         ISETP.GT.AND.EX P0, PT, R16.reuse, R29.reuse, PT, P0 ;
#         ISETP.NE.AND.EX P1, PT, R16, R29, PT, P1 ;
#         ISETP.GT.XOR P0, PT, R61, RZ, P0 ;
# ; Location ./In[98]:11
#     @P0 BRA P1, `(.L_9) ;
# ; Location ./In[98]:24
#         IMAD.MOV.U32 R0, RZ, RZ, c[0x0][0x194] ;
#         ISETP.LT.U32.AND P1, PT, RZ, c[0x0][0x190], PT ;
#         ULDC UR4, c[0x0][0x0] ;
#         IADD3 R27, P4, RZ, -R18, RZ ;
#         ULOP3.LUT UR5, UR4, 0x3e0, URZ, 0xc0, !UPT ;
#         ISETP.GT.AND.EX P1, PT, R0, RZ, PT, P1 ;
#         ULDC UR6, c[0x0][0x0] ;
#         IMAD.MOV.U32 R2, RZ, RZ, c[0x0][0x19c] ;
#         ISETP.LT.U32.AND P0, PT, RZ, c[0x0][0x198], PT ;
#         IMAD.X R0, RZ, RZ, ~R19, P4 ;
#         IADD3 R3, P4, RZ, -R78, RZ ;
#         UISETP.NE.AND UP0, UPT, UR5, UR6, UPT ;
#         IMAD.MOV.U32 R77, RZ, RZ, RZ ;
#         ISETP.GT.AND.EX P0, PT, R2, RZ, PT, P0 ;
#         IMAD R0, R0, c[0x0][0x1e8], RZ ;
#         USHF.R.U32.HI UR5, URZ, 0x5, UR4 ;
#         IMAD.X R2, RZ, RZ, ~R79, P4 ;
#         ISETP.LT.U32.AND P2, PT, RZ, c[0x0][0x1b8], PT ;
#         IMAD.MOV.U32 R68, RZ, RZ, R18 ;
#         MOV R4, c[0x0][0x1bc] ;
#         IMAD.MOV.U32 R69, RZ, RZ, R19 ;
#         ULEA.HI UR4, UR4, 0x1, URZ, 0x1b ;
#         IMAD.WIDE.U32 R70, R27, c[0x0][0x1e8], R76 ;
#         @!UP0 UIADD3 UR4, UR5, URZ, URZ ;
#         ISETP.GT.AND.EX P2, PT, R4, RZ, PT, P2 ;
#         IMAD R27, R27, c[0x0][0x1ec], R0 ;
#         ISETP.LT.U32.AND P3, PT, RZ, c[0x0][0x1c0], PT ;
#         IMAD R0, R2, c[0x0][0x1f0], RZ ;
#         SEL R31, RZ, c[0x0][0x190], !P1 ;
#         IMAD.WIDE.U32 R68, R3.reuse, c[0x0][0x1f0], R68 ;
#         SEL R30, RZ, c[0x0][0x194], !P1 ;
#         SEL R37, RZ, c[0x0][0x198], !P0 ;
#         IMAD.MOV.U32 R5, RZ, RZ, c[0x0][0x1c4] ;
#         SEL R36, RZ, c[0x0][0x19c], !P0 ;
#         IMAD R3, R3, c[0x0][0x1f4], R0 ;
# ; Location ./range.jl:828
#         IADD3 R17, P5, R61, R17, RZ ;
#         IMAD.IADD R27, R71, 0x1, R27 ;
#         SHF.R.S32.HI R46, RZ, 0x1f, R61 ;
#         IMAD.IADD R24, R69, 0x1, R3 ;
#         IADD3 R19, P4, R78, 0x1, RZ ;
#         SEL R39, RZ, c[0x0][0x1b8], !P2 ;
#         IMAD.X R16, R46, 0x1, R16, P5 ;
#         SEL R38, RZ, c[0x0][0x1bc], !P2 ;
#         IMAD.X R18, RZ, RZ, R79, P4 ;
#         IADD3 R26, P0, R70, 0x1, RZ ;
#         IADD3 R23, P1, R68, 0x1, RZ ;
#         ISETP.GT.AND.EX P3, PT, R5, RZ, PT, P3 ;
#         IMAD.X R25, RZ, RZ, R27, P0 ;
# ; Location ./int.jl:87
#         ISETP.GE.U32.AND P2, PT, R55, UR4, PT ;
#         IMAD.X R22, RZ, RZ, R24, P1 ;
#         MOV R60, RZ ;
#         SEL R45, RZ, c[0x0][0x1c0], !P3 ;
#         SEL R44, RZ, c[0x0][0x1c4], !P3 ;
#         P2R R63, PR, RZ, 0x4 ;
#
# .L_21:
# ; Location ./int.jl:86
#         IADD3 R33, P0, R28, -0x1, RZ ;
#         BMOV.32.CLEAR RZ, B0 ;
#         BSSY B0, `(.L_10) ;
#         IADD3.X R34, R29, -0x1, RZ, P0, !PT ;
# ; Location ./int.jl:284
#         LOP3.LUT R0, R34, c[0x0][0x1d4], RZ, 0xfc, !PT ;
#         LOP3.LUT P0, RZ, R0, 0xffffffff, RZ, 0xc0, !PT ;
#     @P0 BRA `(.L_11) ;
#         I2F.U32.RP R0, c[0x0][0x1d0] ;
#         ISETP.NE.U32.AND P2, PT, RZ, c[0x0][0x1d0], PT ;
#         MUFU.RCP R0, R0 ;
#         IADD3 R2, R0, 0xffffffe, RZ ;
#         F2I.FTZ.U32.TRUNC.NTZ R3, R2 ;
#         IMAD.MOV.U32 R2, RZ, RZ, RZ ;
#         IADD3 R5, RZ, -R3, RZ ;
#         IMAD R5, R5, c[0x0][0x1d0], RZ ;
#         IMAD.HI.U32 R3, R3, R5, R2 ;
#         IMAD.HI.U32 R2, R3, R33, RZ ;
#         IMAD.MOV R3, RZ, RZ, -R2 ;
#         IMAD R3, R3, c[0x0][0x1d0], R33 ;
#         ISETP.GE.U32.AND P0, PT, R3, c[0x0][0x1d0], PT ;
#     @P0 IADD3 R3, R3, -c[0x0][0x1d0], RZ ;
#     @P0 IADD3 R2, R2, 0x1, RZ ;
#         ISETP.GE.U32.AND P1, PT, R3, c[0x0][0x1d0], PT ;
#         IMAD.MOV.U32 R3, RZ, RZ, RZ ;
#     @P1 IADD3 R2, R2, 0x1, RZ ;
#    @!P2 LOP3.LUT R2, RZ, c[0x0][0x1d0], RZ, 0x33, !PT ;
#         BRA `(.L_12) ;
#
# .L_11:
#         IMAD.MOV.U32 R32, RZ, RZ, c[0x0][0x1d0] ;
#         MOV R20, 0xa50 ;
#         IMAD.MOV.U32 R21, RZ, RZ, c[0x0][0x1d4] ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64) ;
#         IMAD.MOV.U32 R2, RZ, RZ, R6 ;
#         MOV R3, R7 ;
#
# .L_12:
#         BSYNC B0 ;
#
# .L_10:
# ; Location ./int.jl:87
#         ULDC.64 UR4, c[0x0][0x1d0] ;
# ; Location ./int.jl:284
#         LOP3.LUT R0, R3, c[0x0][0x1dc], RZ, 0xfc, !PT ;
# ; Location ./int.jl:87
#         UIADD3 UR4, UP0, URZ, -UR4, URZ ;
#         BMOV.32.CLEAR RZ, B0 ;
#         BSSY B0, `(.L_13) ;
# ; Location ./int.jl:284
#         LOP3.LUT P0, RZ, R0, 0xffffffff, RZ, 0xc0, !PT ;
# ; Location ./int.jl:87
#         UIADD3.X UR5, URZ, ~UR5, URZ, UP0, !UPT ;
#         IMAD R7, R3, UR4, RZ ;
#         IMAD.WIDE.U32 R4, R2, UR4, R28 ;
#         IMAD R7, R2, UR5, R7 ;
#         IADD3 R11, P1, R4, -0x1, RZ ;
#         IMAD.IADD R10, R5, 0x1, R7 ;
#         IADD3.X R0, R10, -0x1, RZ, P1, !PT ;
# ; Location ./int.jl:284
#     @P0 BRA `(.L_14) ;
#         I2F.U32.RP R8, c[0x0][0x1d8] ;
#         ISETP.NE.U32.AND P2, PT, RZ, c[0x0][0x1d8], PT ;
#         MUFU.RCP R8, R8 ;
#         IADD3 R6, R8, 0xffffffe, RZ ;
#         F2I.FTZ.U32.TRUNC.NTZ R7, R6 ;
#         IMAD.MOV.U32 R6, RZ, RZ, RZ ;
#         IMAD.MOV R9, RZ, RZ, -R7 ;
#         IMAD R9, R9, c[0x0][0x1d8], RZ ;
#         IMAD.HI.U32 R7, R7, R9, R6 ;
#         IMAD.HI.U32 R6, R7, R2, RZ ;
#         IMAD.MOV R7, RZ, RZ, -R6 ;
#         IMAD R7, R7, c[0x0][0x1d8], R2 ;
#         ISETP.GE.U32.AND P0, PT, R7, c[0x0][0x1d8], PT ;
#     @P0 IADD3 R7, R7, -c[0x0][0x1d8], RZ ;
#     @P0 IADD3 R6, R6, 0x1, RZ ;
#         ISETP.GE.U32.AND P1, PT, R7, c[0x0][0x1d8], PT ;
#         IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#     @P1 IADD3 R6, R6, 0x1, RZ ;
#    @!P2 LOP3.LUT R6, RZ, c[0x0][0x1d8], RZ, 0x33, !PT ;
#         BRA `(.L_15) ;
#
# .L_14:
#         IMAD.MOV.U32 R33, RZ, RZ, R2 ;
#         MOV R34, R3 ;
#         IMAD.MOV.U32 R32, RZ, RZ, c[0x0][0x1d8] ;
#         MOV R20, 0xd00 ;
#         IMAD.MOV.U32 R21, RZ, RZ, c[0x0][0x1dc] ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64) ;
#
# .L_15:
#         BSYNC B0 ;
#
# .L_13:
# ; Location ./int.jl:86
#         IADD3 R9, P0, RZ, -R6, RZ ;
#         IMAD.X R5, RZ, RZ, ~R7, P0 ;
# ; Location ./int.jl:87
#         IADD3 R8, P0, R6, 0x1, RZ ;
# ; Location ./int.jl:86
#         IMAD.WIDE.U32 R2, R9, c[0x0][0x1d8], R2 ;
# ; Location ./int.jl:83
#         ISETP.GE.U32.AND P1, PT, R19, R8, PT ;
# ; Location ./int.jl:86
#         IMAD R5, R5, c[0x0][0x1d8], RZ ;
# ; Location ./int.jl:87
#         IADD3 R8, P2, R2, 0x1, RZ ;
# ; Location ./int.jl:86
#         IMAD R9, R9, c[0x0][0x1dc], R5 ;
# ; Location ./int.jl:87
#         IMAD.X R5, RZ, RZ, R7, P0 ;
# ; Location ./int.jl:83
#         ISETP.GE.U32.AND P0, PT, R23, R8, PT ;
# ; Location ./int.jl:86
#         IMAD.IADD R9, R3, 0x1, R9 ;
# ; Location ./int.jl:83
#         ISETP.GE.AND.EX P1, PT, R18, R5, PT, P1 ;
# ; Location ./int.jl:87
#         IMAD.X R3, RZ, RZ, R9, P2 ;
# ; Location ./int.jl:83
#         ISETP.GE.U32.AND P2, PT, R26, R4, PT ;
# ; Location ./int.jl:86
#         SEL R8, R7, R79, !P1 ;
# ; Location ./int.jl:83
#         ISETP.GE.AND.EX P0, PT, R22, R3, PT, P0 ;
# ; Location ./int.jl:86
#         SEL R7, R6, R78, !P1 ;
#         SEL R4, R2, R68, !P0 ;
# ; Location ./int.jl:88
#         IMAD R2, R8.reuse, R37, RZ ;
# ; Location ./int.jl:86
#         SEL R5, R9, R24, !P0 ;
# ; Location ./int.jl:88
#         IMAD R8, R8, R45, RZ ;
# ; Location ./int.jl:83
#         ISETP.GE.AND.EX P0, PT, R25, R10, PT, P2 ;
# ; Location ./int.jl:88
#         IMAD R13, R7, R36, R2 ;
#         IMAD.WIDE.U32 R2, R7, R37, R4 ;
# ; Location ./int.jl:87
#         SEL R9, R0, R27, !P0 ;
# ; Location ./int.jl:88
#         IMAD.WIDE.U32 R4, R7, R45, R4 ;
#         IADD3 R10, R3, R13, RZ ;
#         IMAD R7, R7, R44, R8 ;
# ; Location ./int.jl:87
#         SEL R8, R11, R70, !P0 ;
# ; Location ./int.jl:88
#         IMAD.IADD R0, R5, 0x1, R7 ;
# ; Location ./int.jl:86
#         IMAD R3, R10, R31, RZ ;
#         IMAD R5, R0, R39, RZ ;
#         IMAD.WIDE.U32 R6, R31, R2, R8 ;
#         IMAD.WIDE.U32 R8, R39, R4, R8 ;
#         IMAD R3, R30, R2, R3 ;
#         IMAD R11, R38, R4, R5 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         LEA R4, P0, R6, c[0x0][0x180], 0x2 ;
# ; Location ./int.jl:86
#         IMAD.IADD R5, R7, 0x1, R3 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         LEA R10, P1, R8, c[0x0][0x1a8], 0x2 ;
# ; Location ./int.jl:86
#         IMAD.IADD R3, R9, 0x1, R11 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         LEA.HI.X R5, R6, c[0x0][0x184], R5, 0x2, P0 ;
#         LEA.HI.X R11, R8, c[0x0][0x1ac], R3, 0x2, P1 ;
#         LDG.E.SYS R2, [R4] ;
#         LDG.E.SYS R11, [R10] ;
# ; Location /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:25
#         BMOV.32.CLEAR RZ, B7 ;
#         BSSY B7, `(.L_16) ;
#         MOV R52, 0x1020 ;
# ; Location ./float.jl:401
#         FADD R2, R2, -R11 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:25
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750) ;
#         BSYNC B7 ;
#
# .L_16:
# ; Location ./float.jl:404
#         FMUL R7, R2, R2 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         BRA.DIV `(.L_17) ;
#         SHFL.DOWN PT, R0, R7, 0x1, 0x1f ;
# ; Location ./float.jl:398
#         FADD R0, R7, R0 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R3, R0, 0x2, 0x1f ;
# ; Location ./float.jl:398
#         FADD R3, R0, R3 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R2, R3, 0x4, 0x1f ;
# ; Location ./float.jl:398
#         FADD R2, R3, R2 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R5, R2, 0x8, 0x1f ;
# ; Location ./float.jl:398
#         FADD R5, R2, R5 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R4, R5, 0x10, 0x1f ;
#
# .L_22:
# ; Location ./promotion.jl:468
#         ISETP.NE.AND P0, PT, R47, 0x1, PT ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:14
#         WARPSYNC 0xffffffff ;
#         ISETP.NE.AND P1, PT, R63, RZ, PT ;
#         BMOV.32.CLEAR RZ, B0 ;
#         BSSY B0, `(.L_18) ;
#    @!P0 IADD3 R0, R53, -0x1, RZ ;
#    @!P0 FADD R4, R4, R5 ;
#         MOV R5, RZ ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#    @!P0 IMAD.SHL.U32 R3, R0, 0x4, RZ ;
#    @!P1 IADD3 R0, R47, -0x1, RZ ;
#    @!P1 IMAD.SHL.U32 R0, R0, 0x4, RZ ;
#    @!P0 STS [R3], R4 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:14
#         BAR.SYNC 0x0 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#    @!P1 LDS.U R5, [R0] ;
# ; Location ./promotion.jl:468
#         ISETP.NE.AND P0, PT, R53, 0x1, PT ;
# ; Location /home/tim/Julia/pkg/CUDA/src/mapreduce.jl:46
#     @P0 BRA `(.L_19) ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         BRA.DIV `(.L_20) ;
#         SHFL.DOWN PT, R0, R5, 0x1, 0x1f ;
# ; Location ./float.jl:398
#         FADD R0, R5, R0 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R3, R0, 0x2, 0x1f ;
# ; Location ./float.jl:398
#         FADD R3, R0, R3 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R2, R3, 0x4, 0x1f ;
# ; Location ./float.jl:398
#         FADD R2, R3, R2 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R7, R2, 0x8, 0x1f ;
# ; Location ./float.jl:398
#         FADD R7, R2, R7 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         SHFL.DOWN PT, R4, R7, 0x10, 0x1f ;
#
# .L_23:
# ; Location ./float.jl:398
#         FADD R5, R4, R7 ;
#
# .L_19:
#         BSYNC B0 ;
#
# .L_18:
# ; Location ./range.jl:832
#         IADD3 R28, P0, R61, R28, RZ ;
# ; Location ./float.jl:398
#         FADD R60, R5, R60 ;
# ; Location ./range.jl:832
#         IMAD.X R29, R46, 0x1, R29, P0 ;
# ; Location ./promotion.jl:468
#         ISETP.NE.U32.AND P0, PT, R17, R28, PT ;
#         ISETP.NE.AND.EX P0, PT, R16, R29, PT, P0 ;
#     @P0 YIELD ;
# ; Location ./In[98]:16
#     @P0 BRA `(.L_21) ;
#
# .L_9:
# ; Location ./promotion.jl:468
#         ISETP.NE.AND P0, PT, R55, RZ, PT ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:14
#         WARPSYNC 0xffffffff ;
#         BAR.SYNC 0x0 ;
# ; Location ./In[98]:21
#     @P0 EXIT ;
#         LEA R76, P0, R76, c[0x0][0x168], 0x2 ;
#         IMAD.X R77, RZ, RZ, c[0x0][0x16c], P0 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         RED.E.ADD.F32.FTZ.RN.STRONG.GPU [R76], R60 ;
# ; Location ./In[98]:24
#         EXIT ;
#
# .L_17:
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/warp_shuffle.jl:29
#         IMAD.MOV.U32 R5, RZ, RZ, R7 ;
#         MOV R3, 0xffffffff ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x1 ;
#         MOV R2, 0x13f0 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R7, R4 ;
#         MOV R2, 0x1450 ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x2 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R2, 0x14b0 ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x4 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R0, 0x8 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         MOV R2, 0x1510 ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R2, 0x1570 ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x10 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         BRA `(.L_22) ;
#
# .L_20:
#         IMAD.MOV.U32 R0, RZ, RZ, 0x1 ;
#         MOV R2, 0x15d0 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R3, 0xffffffff ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x2 ;
#         MOV R2, 0x1630 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R2, 0x1690 ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x4 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R5, R5, R4 ;
#         MOV R2, 0x16f0 ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x8 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         FADD R7, R5, R4 ;
#         MOV R0, 0x10 ;
#         IMAD.MOV.U32 R4, RZ, RZ, 0x1f ;
#         MOV R2, 0x1760 ;
#         IMAD.MOV.U32 R3, RZ, RZ, -0x1 ;
#         IMAD.MOV.U32 R5, RZ, RZ, R7 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down) ;
#         BRA `(.L_23) ;
#         .weak           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64 - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_div_s64:
#         IADD3 R7, P1, RZ, -R32.reuse, RZ ;
#         ISETP.GE.AND P0, PT, R21, RZ, PT ;
#         ISETP.GE.AND P3, PT, R34, RZ, PT ;
#         IMAD.X R8, RZ, RZ, ~R21, P1 ;
#         SEL R6, R7, R32, !P0 ;
#         SEL R7, R8, R21, !P0 ;
#         I2F.U64.RP R14, R6 ;
#         MUFU.RCP R14, R14 ;
#         IADD3 R8, R14, 0x1ffffffe, RZ ;
#         F2I.U64.TRUNC R8, R8 ;
#         IMAD.WIDE.U32 R12, R8, R6, RZ ;
#         IMAD R13, R8, R7, R13 ;
#         IADD3 R15, P0, RZ, -R12, RZ ;
#         IMAD R13, R9, R6, R13 ;
#         IMAD.HI.U32 R12, R8, R15, RZ ;
#         IADD3.X R35, RZ, ~R13, RZ, P0, !PT ;
#         IMAD.MOV.U32 R13, RZ, RZ, R8 ;
#         IMAD.WIDE.U32 R12, P0, R8, R35, R12 ;
#         IMAD.HI.U32 R8, R9, R35, RZ ;
#         IMAD.HI.U32 R12, P1, R9, R15, R12 ;
#         IMAD R13, R9, R35, RZ ;
#         IMAD.X R8, R8, 0x1, R9, P0 ;
#         IADD3 R13, P2, R13, R12, RZ ;
#         IADD3.X R9, RZ, RZ, R8, P2, P1 ;
#         IMAD.WIDE.U32 R14, R13, R6, RZ ;
#         IMAD R8, R13, R7, R15 ;
#         IADD3 R15, P0, RZ, -R14, RZ ;
#         IMAD R8, R9, R6, R8 ;
#         IMAD.HI.U32 R12, R13, R15, RZ ;
#         IMAD.X R14, RZ, RZ, ~R8, P0 ;
#         IADD3 R8, P4, RZ, -R33, RZ ;
#         IMAD.WIDE.U32 R12, P0, R13, R14, R12 ;
#         SEL R35, R8, R33, !P3 ;
#         IMAD.HI.U32 R13, P1, R9, R15, R12 ;
#         IMAD R12, R9, R14, RZ ;
#         IMAD.X R15, RZ, RZ, ~R34, P4 ;
#         IADD3 R13, P2, R12, R13, RZ ;
#         IMAD.HI.U32 R12, R9, R14, RZ ;
#         SEL R14, R15, R34, !P3 ;
#         IMAD.HI.U32 R8, R13, R35, RZ ;
#         IMAD.X R12, R12, 0x1, R9, P0 ;
#         IMAD.MOV.U32 R9, RZ, RZ, RZ ;
#         IMAD.WIDE.U32 R8, R13, R14, R8 ;
#         IADD3.X R13, RZ, RZ, R12, P2, P1 ;
#         IMAD.HI.U32 R12, R13, R14, RZ ;
#         IMAD.HI.U32 R8, P0, R13, R35, R8 ;
#         IMAD R9, R13, R14, RZ ;
#         IADD3.X R12, R12, RZ, RZ, P0, !PT ;
#         IADD3 R13, P1, R9, R8, RZ ;
#         IMAD.WIDE.U32 R8, R13, R6, RZ ;
#         IMAD.X R15, RZ, RZ, R12, P1 ;
#         IMAD R9, R13.reuse, R7, R9 ;
#         IADD3 R35, P1, -R8, R35, RZ ;
#         IADD3 R8, P2, R13, 0x1, RZ ;
#         IMAD R9, R15, R6.reuse, R9 ;
#         ISETP.GE.U32.AND P0, PT, R35, R6, PT ;
#         IMAD.X R41, R14, 0x1, ~R9, P1 ;
#         IADD3 R9, P1, R35, -R6, RZ ;
#         IMAD.X R12, RZ, RZ, R15, P2 ;
#         ISETP.GE.U32.AND.EX P0, PT, R41.reuse, R7, PT, P0 ;
#         IMAD.X R33, R41, 0x1, ~R7, P1 ;
#         SEL R9, R9, R35, P0 ;
#         SEL R13, R8, R13, P0 ;
#         SEL R33, R33, R41, P0 ;
#         ISETP.GE.U32.AND P1, PT, R9, R6, PT ;
#         SEL R8, R12, R15, P0 ;
#         IADD3 R6, P2, R13, 0x1, RZ ;
#         ISETP.GE.U32.AND.EX P0, PT, R33, R7, PT, P1 ;
#         LOP3.LUT R12, R21, R34, RZ, 0x3c, !PT ;
#         IMAD.X R7, RZ, RZ, R8, P2 ;
#         SEL R6, R6, R13, P0 ;
#         ISETP.GE.AND P1, PT, R12, RZ, PT ;
#         SEL R7, R7, R8, P0 ;
#         IADD3 R9, P2, RZ, -R6, RZ ;
#         ISETP.NE.U32.AND P0, PT, R32, RZ, PT ;
#         SEL R6, R9, R6, !P1 ;
#         IMAD.X R8, RZ, RZ, ~R7, P2 ;
#         ISETP.NE.AND.EX P0, PT, R21, RZ, PT, P0 ;
#         MOV R21, 0x0 ;
#         SEL R7, R8, R7, !P1 ;
#         SEL R6, R6, 0xffffffff, P0 ;
#         SEL R7, R7, 0xffffffff, P0 ;
#         RET.REL.NODEC R20 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .weak           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64 - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_s64:
#         IADD3 R4, P2, RZ, -R7, RZ ;
#         ISETP.GE.AND P1, PT, R20, RZ, PT ;
#         IMAD.X R5, RZ, RZ, ~R20, P2 ;
#         SEL R4, R4, R7, !P1 ;
#         SEL R5, R5, R20, !P1 ;
#         I2F.U64.RP R6, R4 ;
#         MUFU.RCP R6, R6 ;
#         IADD3 R8, R6, 0x1ffffffe, RZ ;
#         F2I.U64.TRUNC R8, R8 ;
#         IMAD.WIDE.U32 R10, R8, R4, RZ ;
#         IMAD R11, R8, R5, R11 ;
#         IADD3 R13, P1, RZ, -R10, RZ ;
#         IMAD R11, R9, R4, R11 ;
#         IMAD.HI.U32 R10, R8, R13, RZ ;
#         IMAD.X R15, RZ, RZ, ~R11, P1 ;
#         IMAD.MOV.U32 R11, RZ, RZ, R8 ;
#         IMAD.WIDE.U32 R10, P1, R8, R15, R10 ;
#         IMAD.HI.U32 R8, R9, R15, RZ ;
#         IMAD.HI.U32 R10, P2, R9, R13, R10 ;
#         IMAD R13, R9, R15, RZ ;
#         IMAD.X R8, R8, 0x1, R9, P1 ;
#         IADD3 R13, P3, R13, R10, RZ ;
#         IADD3.X R9, RZ, RZ, R8, P3, P2 ;
#         IMAD.WIDE.U32 R10, R13, R4, RZ ;
#         ISETP.GE.AND P2, PT, R3, RZ, PT ;
#         IMAD R6, R13, R5, R11 ;
#         IADD3 R11, P1, RZ, -R10, RZ ;
#         IMAD R6, R9, R4, R6 ;
#         IMAD.HI.U32 R12, R13, R11, RZ ;
#         IMAD.X R8, RZ, RZ, ~R6, P1 ;
#         IMAD.WIDE.U32 R12, P1, R13, R8, R12 ;
#         IMAD R6, R9, R8, RZ ;
#         IMAD.HI.U32 R11, P3, R9, R11, R12 ;
#         IADD3 R13, P5, RZ, -R0, RZ ;
#         SEL R13, R13, R0, !P2 ;
#         IMAD.HI.U32 R0, R9, R8, RZ ;
#         IADD3 R11, P4, R6, R11, RZ ;
#         IMAD.X R6, RZ, RZ, ~R3, P5 ;
#         IMAD.HI.U32 R8, R11, R13, RZ ;
#         IADD3.X R0, R0, R9, RZ, P1, !PT ;
#         SEL R6, R6, R3, !P2 ;
#         IMAD.MOV.U32 R9, RZ, RZ, RZ ;
#         IADD3.X R3, RZ, RZ, R0, P4, P3 ;
#         IMAD.WIDE.U32 R8, R11, R6, R8 ;
#         IMAD.HI.U32 R0, R3, R6, RZ ;
#         IMAD.HI.U32 R8, P1, R3, R13, R8 ;
#         IMAD R9, R3, R6, RZ ;
#         IMAD.X R0, RZ, RZ, R0, P1 ;
#         IADD3 R3, P3, R9, R8, RZ ;
#         IMAD.WIDE.U32 R8, R3, R4, RZ ;
#         IMAD.X R11, RZ, RZ, R0, P3 ;
#         IMAD R3, R3, R5, R9 ;
#         IADD3 R13, P3, -R8, R13, RZ ;
#         IMAD R3, R11, R4.reuse, R3 ;
#         ISETP.GE.U32.AND P1, PT, R13, R4, PT ;
#         IMAD.X R3, R6, 0x1, ~R3, P3 ;
#         IADD3 R9, P3, R13, -R4, RZ ;
#         ISETP.GE.U32.AND.EX P1, PT, R3.reuse, R5, PT, P1 ;
#         IMAD.X R11, R3, 0x1, ~R5, P3 ;
#         SEL R9, R9, R13, P1 ;
#         SEL R11, R11, R3, P1 ;
#         ISETP.GE.U32.AND P1, PT, R9.reuse, R4.reuse, PT ;
#         IADD3 R0, P3, R9, -R4, RZ ;
#         ISETP.GE.U32.AND.EX P1, PT, R11.reuse, R5.reuse, PT, P1 ;
#         IADD3.X R3, R11, ~R5, RZ, P3, !PT ;
#         SEL R0, R0, R9, P1 ;
#         SEL R3, R3, R11, P1 ;
#         IADD3 R5, P3, RZ, -R0.reuse, RZ ;
#         ISETP.NE.U32.AND P1, PT, R7, RZ, PT ;
#         SEL R0, R5, R0, !P2 ;
#         IMAD.X R4, RZ, RZ, ~R3, P3 ;
#         ISETP.NE.AND.EX P1, PT, R20, RZ, PT, P1 ;
#         IMAD.MOV.U32 R5, RZ, RZ, 0x0 ;
#         SEL R3, R4, R3, !P2 ;
#         IMAD.MOV.U32 R4, RZ, RZ, R14 ;
#         SEL R0, R0, 0xffffffff, P1 ;
#         SEL R3, R3, 0xffffffff, P1 ;
#         RET.REL.NODEC R4 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .weak           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm20_rem_u64:
#         IMAD.MOV.U32 R8, RZ, RZ, R21 ;
#         IMAD.MOV.U32 R9, RZ, RZ, R11 ;
#         I2F.U64.RP R8, R8 ;
#         MUFU.RCP R4, R8 ;
#         IADD3 R4, R4, 0x1ffffffe, RZ ;
#         F2I.U64.TRUNC R4, R4 ;
#         IMAD.WIDE.U32 R6, R4, R21, RZ ;
#         IMAD R7, R4, R11, R7 ;
#         IADD3 R13, P1, RZ, -R6, RZ ;
#         IMAD R7, R5, R21, R7 ;
#         IMAD.HI.U32 R6, R4, R13, RZ ;
#         IADD3.X R15, RZ, ~R7, RZ, P1, !PT ;
#         IMAD.MOV.U32 R7, RZ, RZ, R4 ;
#         IMAD.WIDE.U32 R6, P1, R4, R15, R6 ;
#         IMAD R9, R5.reuse, R15.reuse, RZ ;
#         IMAD.HI.U32 R4, R5, R15, RZ ;
#         IMAD.HI.U32 R6, P2, R5, R13, R6 ;
#         IMAD.X R4, R4, 0x1, R5, P1 ;
#         IADD3 R9, P3, R9, R6, RZ ;
#         IADD3.X R5, RZ, RZ, R4, P3, P2 ;
#         IMAD.WIDE.U32 R6, R9, R21, RZ ;
#         IMAD R4, R9, R11, R7 ;
#         IADD3 R7, P1, RZ, -R6, RZ ;
#         IMAD R4, R5, R21, R4 ;
#         IMAD.HI.U32 R8, R9, R7, RZ ;
#         IMAD.X R4, RZ, RZ, ~R4, P1 ;
#         IMAD.WIDE.U32 R8, P1, R9, R4, R8 ;
#         IMAD R6, R5, R4, RZ ;
#         IMAD.HI.U32 R7, P2, R5, R7, R8 ;
#         IADD3 R7, P3, R6, R7, RZ ;
#         IMAD.HI.U32 R6, R5, R4, RZ ;
#         IMAD.HI.U32 R4, R7, R0, RZ ;
#         IMAD.X R6, R6, 0x1, R5, P1 ;
#         IMAD.MOV.U32 R5, RZ, RZ, RZ ;
#         IADD3.X R6, RZ, RZ, R6, P3, P2 ;
#         IMAD.WIDE.U32 R4, R7, R3, R4 ;
#         IMAD R7, R6, R3, RZ ;
#         IMAD.HI.U32 R4, P1, R6, R0, R4 ;
#         IMAD.HI.U32 R6, R6, R3, RZ ;
#         IADD3 R7, P2, R7, R4, RZ ;
#         IADD3.X R6, R6, RZ, RZ, P1, !PT ;
#         IMAD.WIDE.U32 R4, R7, R21, RZ ;
#         IMAD.X R6, RZ, RZ, R6, P2 ;
#         IMAD R7, R7, R11, R5 ;
#         IADD3 R0, P2, -R4, R0, RZ ;
#         IMAD R6, R6, R21.reuse, R7 ;
#         ISETP.GE.U32.AND P1, PT, R0, R21, PT ;
#         IMAD.X R6, R3, 0x1, ~R6, P2 ;
#         IADD3 R5, P2, -R21, R0, RZ ;
#         ISETP.GE.U32.AND.EX P1, PT, R6.reuse, R11, PT, P1 ;
#         IMAD.X R4, R6, 0x1, ~R11, P2 ;
#         ISETP.NE.U32.AND P2, PT, R21, RZ, PT ;
#         SEL R5, R5, R0, P1 ;
#         SEL R4, R4, R6, P1 ;
#         IADD3 R0, P3, -R21, R5, RZ ;
#         ISETP.GE.U32.AND P1, PT, R5, R21, PT ;
#         ISETP.NE.AND.EX P2, PT, R11, RZ, PT, P2 ;
#         IMAD.X R3, R4.reuse, 0x1, ~R11, P3 ;
#         ISETP.GE.U32.AND.EX P1, PT, R4, R11, PT, P1 ;
#         SEL R0, R0, R5, P1 ;
#         SEL R3, R3, R4, P1 ;
#         IMAD.MOV.U32 R4, RZ, RZ, R10 ;
#         MOV R5, 0x0 ;
#         SEL R0, R0, 0xffffffff, P2 ;
#         SEL R3, R3, 0xffffffff, P2 ;
#         RET.REL.NODEC R4 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .weak           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$__cuda_sm70_shflsync_down:
#         WARPSYNC R3 ;
#         SHFL.DOWN PT, R4, R5, R0, R4 ;
#         IMAD.MOV.U32 R3, RZ, RZ, 0x0 ;
#         RET.REL.NODEC R2 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception:
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         STL.64 [R1], R8 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:49
#         IADD3 R6, P0, R1, c[0x0][0x20], RZ ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         UMOV UR4, 32@lo(__unnamed_1) ;
#         MOV R20, 32@lo((_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE + .L_4@srel)) ;
#         UMOV UR5, 32@hi(__unnamed_1) ;
#         IMAD.U32 R4, RZ, RZ, UR4 ;
#         MOV R21, 32@hi((_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE + .L_4@srel)) ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:49
#         IMAD.X R7, RZ, RZ, c[0x0][0x24], P0 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         IMAD.U32 R5, RZ, RZ, UR5 ;
#         CALL.ABS.NOINC `(vprintf) ;
#
# .L_4:
#         IMAD.MOV.U32 R4, RZ, RZ, R54 ;
#         MOV R5, 0x0 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:54
#         RET.REL.NODEC R4 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750 - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception:
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:37
#         ISETP.NE.U32.AND P0, PT, R4, RZ, PT ;
#         ISETP.NE.AND.EX P0, PT, R5, RZ, PT, P0 ;
#    @!P0 BRA `(.L_24) ;
#         IMAD.MOV.U32 R0, RZ, RZ, 0x1 ;
# ; Location ./pointer.jl:118
#         ST.E.U8.SYS [R4+0x7], RZ ;
#         ST.E.U8.SYS [R4+0x6], RZ ;
#         ST.E.U8.SYS [R4+0x5], RZ ;
#         ST.E.U8.SYS [R4+0x4], RZ ;
#         ST.E.U8.SYS [R4+0x3], RZ ;
#         ST.E.U8.SYS [R4+0x2], RZ ;
#         ST.E.U8.SYS [R4+0x1], RZ ;
#         ST.E.U8.SYS [R4], R0 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/synchronization.jl:121
#         MEMBAR.SC.SYS ;
#         IMAD.MOV.U32 R4, RZ, RZ, R54 ;
#         ERRBAR;
#         IMAD.MOV.U32 R5, RZ, RZ, 0x0 ;
#         CCTL.IVALL ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:39
#         RET.REL.NODEC R4 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#
# .L_24:
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         UMOV UR4, 32@lo(__unnamed_2) ;
#         CS2R R6, SRZ ;
#         UMOV UR5, 32@hi(__unnamed_2) ;
#         IMAD.U32 R4, RZ, RZ, UR4 ;
#         MOV R20, 32@lo((_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE + .L_5@srel)) ;
#         IMAD.U32 R5, RZ, RZ, UR5 ;
#         MOV R21, 32@hi((_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE + .L_5@srel)) ;
#         CALL.ABS.NOINC `(vprintf) ;
#
# .L_5:
#         MOV R4, R54 ;
#         IMAD.MOV.U32 R5, RZ, RZ, 0x0 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/runtime.jl:46
#         RET.REL.NODEC R4 `(_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE) ;
#         .type           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750,@function
#         .size           $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750,($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_steprange_last_14752 - $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750)
# $_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$julia_fldmod1_14750:
# ; Location ./operators.jl:926
#         ISETP.NE.OR P0, PT, R62, -0x80000000, PT ;
#         ISETP.NE.AND P1, PT, RZ, 0x20, PT ;
# ; Location ./int.jl:284
#     @P0 BRA P1, `(.L_25) ;
#         UMOV UR4, 32@lo(exception1) ;
#         MOV R54, 0x2910 ;
#         UMOV UR5, 32@hi(exception1) ;
#         IMAD.U32 R8, RZ, RZ, UR4 ;
#         IMAD.U32 R9, RZ, RZ, UR5 ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_report_exception) ;
#         BMOV.32.CLEAR RZ, B6 ;
#         BSSY B6, `(.L_26) ;
#         IMAD.MOV.U32 R4, RZ, RZ, c[0x0][0x160] ;
#         MOV R54, 0x2970 ;
#         IMAD.MOV.U32 R5, RZ, RZ, c[0x0][0x164] ;
#         CALL.REL.NOINC `($_Z27julia_rmse_kernel_opt_1466213CuDeviceArrayI7Float32Li1ELi1EES_IS0_Li3ELi1EES_IS0_Li3ELi1EE16CartesianIndicesILi3E5TupleI5OneToI5Int64ES3_IS4_ES3_IS4_EEES1_ILi3ES2_IS3_IS4_ES3_IS4_ES3_IS4_EEE$gpu_signal_exception) ;
#         BSYNC B6 ;
#
# .L_26:
#         EXIT ;
#
# .L_25:
#         I2F.RP R0, 0x20 ;
#         IABS R6, R62 ;
#         MUFU.RCP R0, R0 ;
#         IADD3 R4, R0, 0xffffffe, RZ ;
#         LOP3.LUT R0, R62, 0x20, RZ, 0x3c, !PT ;
#         F2I.FTZ.U32.TRUNC.NTZ R5, R4 ;
#         ISETP.GE.AND P2, PT, R0, RZ, PT ;
#         IMAD.MOV.U32 R4, RZ, RZ, RZ ;
#         LEA R3, -R5, RZ, 0x5 ;
#         IMAD.HI.U32 R5, R5, R3, R4 ;
# ; Location ./operators.jl:889
#         MOV R4, R52 ;
# ; Location ./int.jl:284
#         IMAD.HI.U32 R5, R5, R6, RZ ;
#         IMAD R3, R5, -0x20, R6 ;
#         ISETP.LT.U32.AND P1, PT, R3, 0x20, PT ;
#    @!P1 IADD3 R3, R3, -0x20, RZ ;
#    @!P1 IADD3 R5, R5, 0x1, RZ ;
#         ISETP.GE.U32.AND P0, PT, R3, 0x20, PT ;
#     @P0 IADD3 R5, R5, 0x1, RZ ;
#    @!P2 IMAD.MOV R5, RZ, RZ, -R5 ;
#         IMAD.SHL.U32 R3, R5.reuse, 0x20, RZ ;
# ; Location ./int.jl:87
#         IADD3 R53, R5, 0x1, RZ ;
# ; Location ./promotion.jl:468
#         ISETP.NE.AND P0, PT, R3, R62, PT ;
#         IADD3 R3, R5, -0x1, RZ ;
#         ISETP.LT.AND P1, PT, R0.reuse, RZ, P0 ;
#         ISETP.GT.AND P0, PT, R0, -0x1, P0 ;
#    @!P1 IMAD.MOV R3, RZ, RZ, R5.reuse ;
# ; Location ./int.jl:87
#    @!P0 IMAD.MOV R53, RZ, RZ, R5 ;
#         IMAD R3, R3, -0x20, R62 ;
# ; Location ./operators.jl:889
#         IMAD.MOV.U32 R5, RZ, RZ, 0x0 ;
# ...
# 	.elftype	@"ET_EXEC"
#
#
# //--------------------- .text._Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_ --------------------------
# 	.section	.text._Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=26"
# 	.align	128
#         .global         _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_
#         .type           _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_,@function
#         .size           _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_,(.L_55 - _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_)
#         .other          _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_:
#
# .text._Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_:
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:56
#         IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
# ; Location ./range.jl:359
#         IMAD.MOV.U32 R0, RZ, RZ, c[0x0][0x1b8] ;
#         IMAD.MOV.U32 R4, RZ, RZ, c[0x0][0x1bc] ;
#         ISETP.GE.U32.AND P0, PT, R0, 0x1, PT ;
#         ISETP.GE.AND.EX P0, PT, R4, RZ, PT, P0 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:57
#    @!P0 EXIT ;
#         LDC.U8 R3, c[0x0][0x198] ;
#         S2R R6, SR_TID.X ;
#         I2F.S64 R0, c[0x0][0x1a8] ;
#         IMAD.MOV.U32 R2, RZ, RZ, c[0x0][0x0] ;
#         ISETP.LT.U32.AND P0, PT, RZ, c[0x0][0x1b8], PT ;
#         S2R R9, SR_CTAID.X ;
#         IMAD R2, R2, c[0x0][0xc], RZ ;
#         ISETP.GT.AND.EX P0, PT, R4, RZ, PT, P0 ;
#         SEL R4, RZ, c[0x0][0x1bc], !P0 ;
#         SHF.R.S32.HI R5, RZ, 0x1f, R2 ;
#         LOP3.LUT R3, R3, 0x1, RZ, 0xc0, !PT ;
#         IADD3 R6, R6, 0x1, RZ ;
#         ISETP.NE.U32.AND P1, PT, R3, 0x1, PT ;
#         SEL R3, RZ, c[0x0][0x1b8], !P0 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#     @P1 BRA `(.L_3) ;
#         IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         IMAD.WIDE.U32 R6, R9, c[0x0][0x0], R6 ;
#         IADD3 R13, P0, R6, -0x1, RZ ;
#         IMAD.MOV.U32 R6, RZ, RZ, RZ ;
#         IADD3 R9, P1, P2, R13, 0x1, -R2 ;
#         IADD3.X R6, R7, -0x1, R6, P0, !PT ;
# ; Location ./int.jl:83
#         IADD3 R7, P3, R2, R9, RZ ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#         IADD3.X R8, R6, RZ, ~R5, P1, P2 ;
# ; Location ./int.jl:83
#         ISETP.GT.U32.AND P0, PT, R7, c[0x0][0x178], PT ;
#         IMAD.X R8, R5, 0x1, R8, P3 ;
#         ISETP.GT.AND.EX P0, PT, R8, c[0x0][0x17c], PT, P0 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#     @P0 EXIT ;
#         SHF.L.U64.HI R11, R13.reuse, 0x2, R6 ;
#         IMAD.SHL.U32 R12, R13, 0x4, RZ ;
#         SHF.L.U64.HI R6, R2, 0x2, R5 ;
#
# .L_7:
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         IMAD.MOV.U32 R13, RZ, RZ, R11 ;
#         ULDC.64 UR4, c[0x0][0x180] ;
#         LDG.E.SYS R18, [R12.64+UR4] ;
#         IADD3 R7, P0, R2.reuse, R7, RZ ;
#         BMOV.32.CLEAR RZ, B0 ;
#         LEA R9, P3, R2, R12, 0x2 ;
#         BSSY B0, `(.L_4) ;
#         IADD3 R3, P2, R3, -0x1, RZ ;
#         IMAD.X R8, R5, 0x1, R8, P0 ;
#         ISETP.GT.U32.AND P0, PT, R7, c[0x0][0x178], PT ;
#         IMAD.X R10, R11, 0x1, R6, P3 ;
#         IADD3.X R4, R4, -0x1, RZ, P2, !PT ;
#         ISETP.GT.AND.EX P0, PT, R8, c[0x0][0x17c], PT, P0 ;
# ; Location ./float.jl:407
#         FCHK P1, R18, R0 ;
#     @P1 BRA `(.L_5) ;
#         MUFU.RCP R13, R0 ;
#         FADD.FTZ R14, -R0, -RZ ;
#         FFMA R16, R13, R14, 1 ;
#         FFMA R16, R13, R16, R13 ;
#         FFMA R13, R18, R16, RZ ;
#         FFMA R15, R14, R13, R18 ;
#         FFMA R15, R16, R15, R13 ;
#         FFMA R14, R14, R15, R18 ;
#         FFMA R14, R16, R14, R15 ;
#         BRA `(.L_6) ;
#
# .L_5:
#         MOV R14, 0x3f0 ;
#         CALL.REL.NOINC `($_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath) ;
#         IMAD.MOV.U32 R14, RZ, RZ, R18 ;
#
# .L_6:
#         BSYNC B0 ;
#
# .L_4:
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/math.jl:218
#         FSETP.GEU.AND P1, PT, |R14|, 1.175494350822287508e-38, PT ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         IMAD.MOV.U32 R13, RZ, RZ, R11 ;
#         ULDC.64 UR4, c[0x0][0x168] ;
#    @!P1 FMUL R14, R14, 16777216 ;
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/math.jl:218
#         MUFU.SQRT R15, R14 ;
#    @!P1 FMUL R15, R15, 0.000244140625 ;
# ; Location ./promotion.jl:468
#         ISETP.NE.U32.AND P1, PT, R3, RZ, PT ;
#         ISETP.NE.AND.EX P1, PT, R4, RZ, PT, P1 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         STG.E.SYS [R12.64+UR4], R15 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:59
#    @!P1 EXIT ;
# ; Location ./promotion.jl:468
#         IMAD.MOV.U32 R12, RZ, RZ, R9 ;
#         IMAD.MOV.U32 R11, RZ, RZ, R10 ;
#    @!P0 BRA `(.L_7) ;
#         EXIT ;
#
# .L_3:
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#         IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         ULDC.64 UR6, c[0x0][0x1a0] ;
#         ULDC.64 UR4, c[0x0][0x180] ;
#         IMAD.WIDE.U32 R6, R9, c[0x0][0x0], R6 ;
#         ULEA UR4, UP0, UR6, UR4, 0x2 ;
#         ULEA.HI.X UR5, UR6, UR5, UR7, 0x2, UP0 ;
#         IADD3 R13, P0, R6, -0x1, RZ ;
#         IMAD.MOV.U32 R6, RZ, RZ, RZ ;
#         IADD3 R9, P1, P2, R13, 0x1, -R2 ;
#         IADD3.X R6, R7, -0x1, R6, P0, !PT ;
# ; Location ./int.jl:83
#         IADD3 R7, P0, R2, R9, RZ ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#         IADD3.X R8, R6, RZ, ~R5, P1, P2 ;
#         LEA R11, P1, R13, c[0x0][0x168], 0x2 ;
# ; Location ./int.jl:83
#         IMAD.X R8, R5, 0x1, R8, P0 ;
#         ISETP.GT.U32.AND P0, PT, R7, c[0x0][0x178], PT ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#         LEA.HI.X R13, R13, c[0x0][0x16c], R6, 0x2, P1 ;
# ; Location ./int.jl:83
#         ISETP.GT.AND.EX P0, PT, R8, c[0x0][0x17c], PT, P0 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#     @P0 EXIT ;
# ; Location ./int.jl:83
#         IMAD.MOV.U32 R6, RZ, RZ, R8 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/device/indexing.jl:67
#         SHF.L.U64.HI R8, R2, 0x2, R5 ;
#
# .L_10:
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         LDG.E.SYS R15, [UR4+-0x4] ;
#         IADD3 R7, P0, R2.reuse, R7, RZ ;
#         LEA R9, P2, R2, R11, 0x2 ;
#         IADD3 R3, P3, R3, -0x1, RZ ;
#         IMAD.X R6, R5, 0x1, R6, P0 ;
#         ISETP.GT.U32.AND P0, PT, R7, c[0x0][0x178], PT ;
#         IMAD.X R10, R13, 0x1, R8, P2 ;
#         IADD3.X R4, R4, -0x1, RZ, P3, !PT ;
#         ISETP.GT.AND.EX P0, PT, R6, c[0x0][0x17c], PT, P0 ;
# ; Location ./float.jl:407
#         FCHK P1, R15, R0 ;
#     @P1 BRA `(.L_8) ;
#         MUFU.RCP R12, R0 ;
#         FADD.FTZ R19, -R0, -RZ ;
#         FFMA R17, R12, R19, 1 ;
#         FFMA R14, R12, R17, R12 ;
#         FFMA R12, R15, R14, RZ ;
#         FFMA R17, R12, R19, R15 ;
#         FFMA R12, R17, R14, R12 ;
#         FFMA R15, R12, R19, R15 ;
#         FFMA R12, R15, R14, R12 ;
#         BRA `(.L_9) ;
#
# .L_8:
#         IMAD.MOV.U32 R18, RZ, RZ, R15 ;
#         MOV R14, 0x7b0 ;
#         CALL.REL.NOINC `($_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath) ;
#         IMAD.MOV.U32 R12, RZ, RZ, R18 ;
#
# .L_9:
# ; Location /home/tim/Julia/pkg/CUDA/src/device/intrinsics/math.jl:218
#         FSETP.GEU.AND P1, PT, |R12|, 1.175494350822287508e-38, PT ;
#    @!P1 FMUL R12, R12, 16777216 ;
#         MUFU.SQRT R15, R12 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         IMAD.MOV.U32 R12, RZ, RZ, R11 ;
#    @!P1 FMUL R15, R15, 0.000244140625 ;
# ; Location ./promotion.jl:468
#         ISETP.NE.U32.AND P1, PT, R3, RZ, PT ;
#         ISETP.NE.AND.EX P1, PT, R4, RZ, PT, P1 ;
# ; Location /home/tim/Julia/depot/packages/LLVM/wnejv/src/interop/base.jl:45
#         STG.E.SYS [R12], R15 ;
# ; Location /home/tim/Julia/depot/packages/GPUArrays/3sW6s/src/host/broadcast.jl:59
#    @!P1 EXIT ;
# ; Location ./promotion.jl:468
#         IMAD.MOV.U32 R11, RZ, RZ, R9 ;
#         IMAD.MOV.U32 R13, RZ, RZ, R10 ;
#    @!P0 BRA `(.L_10) ;
#         EXIT ;
#         .weak           $_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath
#         .type           $_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath,@function
#         .size           $_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath,(.L_55 - $_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath)
# $_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_$__cuda_sm3x_div_rn_noftz_f32_slowpath:
#         SHF.R.U32.HI R16, RZ, 0x17, R0 ;
#         BMOV.32.CLEAR RZ, B1 ;
#         SHF.R.U32.HI R15, RZ, 0x17, R18 ;
#         BSSY B1, `(.L_11) ;
#         LOP3.LUT R23, R16, 0xff, RZ, 0xc0, !PT ;
#         IMAD.MOV.U32 R16, RZ, RZ, R0 ;
#         LOP3.LUT R21, R15, 0xff, RZ, 0xc0, !PT ;
#         IMAD.MOV.U32 R15, RZ, RZ, R18 ;
#         IADD3 R20, R23, -0x1, RZ ;
#         IADD3 R19, R21, -0x1, RZ ;
#         ISETP.GT.U32.AND P1, PT, R20, 0xfd, PT ;
#         ISETP.GT.U32.OR P1, PT, R19, 0xfd, P1 ;
#    @!P1 IMAD.MOV.U32 R17, RZ, RZ, RZ ;
#    @!P1 BRA `(.L_12) ;
#         FSETP.GTU.FTZ.AND P1, PT, |R18|, +INF , PT ;
#         FSETP.GTU.FTZ.AND P2, PT, |R0|, +INF , PT ;
#         PLOP3.LUT P1, PT, P1, P2, PT, 0xa8, 0x0 ;
#     @P1 BRA `(.L_13) ;
#         LOP3.LUT P1, RZ, R16, 0x7fffffff, R15, 0xc8, !PT ;
#    @!P1 BRA `(.L_14) ;
#         FSETP.NEU.FTZ.AND P3, PT, |R18|, +INF , PT ;
#         FSETP.NEU.FTZ.AND P2, PT, |R0|, +INF , PT ;
#         FSETP.NEU.FTZ.AND P1, PT, |R18|, +INF , PT ;
#    @!P2 BRA !P3, `(.L_14) ;
#         LOP3.LUT P3, RZ, R15, 0x7fffffff, RZ, 0xc0, !PT ;
#         PLOP3.LUT P2, PT, P2, P3, PT, 0x2a, 0x0 ;
#     @P2 BRA `(.L_15) ;
#         LOP3.LUT P2, RZ, R16, 0x7fffffff, RZ, 0xc0, !PT ;
#         PLOP3.LUT P1, PT, P1, P2, PT, 0x2a, 0x0 ;
#     @P1 BRA `(.L_16) ;
#         ISETP.GE.AND P1, PT, R19, RZ, PT ;
#         ISETP.GE.AND P2, PT, R20, RZ, PT ;
#     @P1 IMAD.MOV.U32 R17, RZ, RZ, RZ ;
#    @!P1 FFMA R15, R18, 1.84467440737095516160e+19, RZ ;
#    @!P1 IMAD.MOV.U32 R17, RZ, RZ, -0x40 ;
#    @!P2 FFMA R16, R0, 1.84467440737095516160e+19, RZ ;
#    @!P2 IADD3 R17, R17, 0x40, RZ ;
#
# .L_12:
#         LEA R19, R23, 0xc0800000, 0x17 ;
#         BMOV.32.CLEAR RZ, B2 ;
#         BSSY B2, `(.L_17) ;
#         IMAD.IADD R19, R16, 0x1, -R19 ;
#         IADD3 R16, R21, -0x7f, RZ ;
#         FADD.FTZ R20, -R19, -RZ ;
#         MUFU.RCP R18, R19 ;
#         IMAD R15, R16.reuse, -0x800000, R15 ;
#         IADD3 R16, R16, 0x7f, -R23 ;
#         IMAD.IADD R16, R16, 0x1, R17 ;
#         FFMA R21, R18, R20, 1 ;
#         FFMA R22, R18, R21, R18 ;
#         FFMA R18, R15, R22, RZ ;
#         FFMA R21, R20, R18, R15 ;
#         FFMA R21, R22, R21, R18 ;
#         FFMA R20, R20, R21, R15 ;
#         FFMA R18, R22, R20, R21 ;
#         SHF.R.U32.HI R15, RZ, 0x17, R18 ;
#         LOP3.LUT R15, R15, 0xff, RZ, 0xc0, !PT ;
#         IMAD.IADD R19, R15, 0x1, R16 ;
#         IADD3 R15, R19, -0x1, RZ ;
#         ISETP.GE.U32.AND P1, PT, R15, 0xfe, PT ;
#    @!P1 BRA `(.L_18) ;
#         ISETP.GT.AND P1, PT, R19, 0xfe, PT ;
#     @P1 BRA `(.L_19) ;
#         ISETP.GE.AND P1, PT, R19, 0x1, PT ;
#     @P1 BRA `(.L_20) ;
#         ISETP.GE.AND P1, PT, R19, -0x18, PT ;
#         LOP3.LUT R18, R18, 0x80000000, RZ, 0xc0, !PT ;
#    @!P1 BRA `(.L_20) ;
#         FFMA.RZ R15, R22.reuse, R20.reuse, R21.reuse ;
#         ISETP.NE.AND P3, PT, R19.reuse, RZ, PT ;
#         FFMA.RM R16, R22.reuse, R20.reuse, R21.reuse ;
#         ISETP.NE.AND P2, PT, R19, RZ, PT ;
#         LOP3.LUT R17, R15, 0x7fffff, RZ, 0xc0, !PT ;
#         FFMA.RP R15, R22, R20, R21 ;
#         IADD3 R20, R19, 0x20, RZ ;
#         IMAD.MOV R19, RZ, RZ, -R19 ;
#         LOP3.LUT R17, R17, 0x800000, RZ, 0xfc, !PT ;
#         FSETP.NEU.FTZ.AND P1, PT, R15, R16, PT ;
#         SHF.L.U32 R20, R17, R20, RZ ;
#         SEL R16, R19, RZ, P3 ;
#         ISETP.NE.AND P2, PT, R20, RZ, P2 ;
#         SHF.R.U32.HI R16, RZ, R16, R17 ;
#         PLOP3.LUT P1, PT, P1, P2, PT, 0xa8, 0x0 ;
#         SHF.R.U32.HI R20, RZ, 0x1, R16 ;
#         SEL R15, RZ, 0x1, !P1 ;
#         LOP3.LUT R15, R15, 0x1, R20, 0xf8, !PT ;
#         LOP3.LUT R15, R15, R16, RZ, 0xc0, !PT ;
#         IMAD.IADD R15, R20, 0x1, R15 ;
#         LOP3.LUT R18, R15, R18, RZ, 0xfc, !PT ;
#         BRA `(.L_20) ;
#
# .L_19:
#         LOP3.LUT R18, R18, 0x80000000, RZ, 0xc0, !PT ;
#         LOP3.LUT R18, R18, 0x7f800000, RZ, 0xfc, !PT ;
#         BRA `(.L_20) ;
#
# .L_18:
#         IMAD R18, R16, 0x800000, R18 ;
#
# .L_20:
#         BSYNC B2 ;
#
# .L_17:
#         BRA `(.L_21) ;
#
# .L_16:
#         LOP3.LUT R15, R16, 0x80000000, R15, 0x48, !PT ;
#         LOP3.LUT R18, R15, 0x7f800000, RZ, 0xfc, !PT ;
#         BRA `(.L_21) ;
#
# .L_15:
#         LOP3.LUT R18, R16, 0x80000000, R15, 0x48, !PT ;
#         BRA `(.L_21) ;
#
# .L_14:
#         IMAD.MOV.U32 R18, RZ, RZ, 0x7fffffff ;
#         BRA `(.L_21) ;
#
# .L_13:
#         FADD.FTZ R18, R18, R0 ;
#
# .L_21:
#         BSYNC B1 ;
#
# .L_11:
#         IMAD.MOV.U32 R15, RZ, RZ, 0x0 ;
#         RET.REL.NODEC R14 `(_Z28julia_broadcast_kernel_1485615CuKernelContext13CuDeviceArrayI7Float32Li1ELi1EE11BroadcastedIv5TupleI5OneToI5Int64EE5_sqrtS3_IS2_I12CuArrayStyleILi1EEv2__S3_I8ExtrudedIS0_IS1_Li1ELi1EES3_I4BoolES3_IS5_EES5_EEEES5_) ;
#
# .L_22:
#         BRA `(.L_22);
#
# .L_55:

# %%
b = @benchmark CUDA.@sync rmse_opt(C, A, B)
display(C)
b
# Out:
# 16-element CuArray{Float32, 1, CUDA.Mem.DeviceBuffer}:
#  0.408646
#  0.40841642
#  0.4083755
#  0.40845305
#  0.4080715
#  0.40784878
#  0.4086396
#  0.40831542
#  0.40791884
#  0.40870374
#  0.40852144
#  0.40846443
#  0.40819678
#  0.40815797
#  0.4082014
#  0.40828073
# BenchmarkTools.Trial: 7138 samples with 1 evaluation.
#  Range (min … max):  682.561 μs …  5.596 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     694.527 μs              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   697.309 μs ± 68.943 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                      ▂▅█▆▅▅▃▂
#   ▁▁▁▁▂▂▂▂▂▂▂▃▂▂▂▃▃▃▆█████████▇▅▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁ ▂
#   683 μs          Histogram: frequency by time          714 μs <
#
#  Memory estimate: 3.19 KiB, allocs estimate: 60.
